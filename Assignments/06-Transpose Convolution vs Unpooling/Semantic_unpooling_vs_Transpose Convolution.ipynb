# %% [markdown]
# <a href="https://colab.research.google.com/github/bakikocabasa/Energy-Management-System-for-EV/blob/main/Assignments/06-Transpose%20Convolution%20vs%20Unpooling/Semantic_unpooling_vs_Transpose%20Convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Course**: Deep Learning
#
# [<img align="right" width="400" height="100" src="https://www.tu-braunschweig.de/typo3conf/ext/tu_braunschweig/Resources/Public/Images/Logos/tu_braunschweig_logo.svg">](https://www.tu-braunschweig.de/en/)
#
# [Abdulbaki Kocabasa]() \([a.kocabasa@tu-bs.de](@tu-bs.de)) and [Yao Yue]() (yue.yao@tu-bs.de)
#
# [Technical University of Braunschweig](https://www.tu-braunschweig.de/en/)

# %% [markdown]
# # Assignment 6
#
# ---
#
# Compare Transpose Convolution and Unpooling
#
# link for the drive content
#
# https://drive.google.com/drive/folders/1kqARtL7kyuTN2udaFKIJH5joJvpR6Q7u?usp=sharing

# %% [markdown]
# ## Mount Google Drive to Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My\ Drive/Colabs/DeepLearning_course/Segmentation/
# Out:
# /content/drive/My Drive/Colabs/DeepLearning_course/Segmentation

# %% [markdown]
# # Import packages

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose, concatenate, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.metrics import OneHotMeanIoU, OneHotIoU
# Callbacks
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Visualization
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as patches
# Operation with arrays
import numpy as np
# Paths and files
from os.path import join,basename,splitext
import os
from glob import glob
from natsort import natsorted
# Reading images
import tifffile
from PIL import Image
# Others
import random

# %% [markdown]
# ## Dataset

# %% [markdown]
# We will work with the ISPRS [2D Semantic Labeling benchmark - Vaihingen](https://www.isprs.org/education/benchmarks/UrbanSemLab/2d-sem-label-vaihingen.aspx).
#
# The dataset contains 33 patches (of different sizes), each consisting of a true orthophoto (TOP), extracted from a larger TOP mosaic, and a Digital Surface Model (DSM).
#
# <center>
# <img width=500 src="https://www.isprs.org/education/benchmarks/UrbanSemLab/img/overview_tiles.jpg?width=398.4830805134189&height=500" img>
# </center>
#
# Labelled ground truth is provided for all areas. An example of a patch from the dataset, where a) true orthophoto, b) DSM, and c) ground truth.
#
# <center>
# <img width=600 src="https://www.isprs.org/education/benchmarks/UrbanSemLab/img/examples_top_dsm_gts.png?width=500&height=196.7930029154519" img>
# </center>

# %% [markdown]
# ### Loading the data
#
# To create the train, validation and test sets, we will follow the benchmark guidelines:
#
# <center>
# <img width=600 src="https://www.isprs.org/education/benchmarks/UrbanSemLab/img/table_label_contest_image_overview.png?width=500&height=397.5490196078431" img>
# </center>
#
# So, the areas for training and testing are the following:
#
# |  Set  |   Areas   |
# |-------|-----------|
# | Train | 1,3,5,7,11,13,15,17,21,23,26,28,30,32,34,37 |
# | Test  | 2,4,6,8,10,12,14,16,20,22,24,27,29,31,33,35,38 |

# %% [markdown]
# The folder structure is the following:
#
# - _dsm_: Digital Surface Models with information about the height of each geographical area.
# - _gts_: Ground Truths or References with information about the semantic class of each pixel.
# - _top_: True Orthophoto with a False RGB Color composition with near infrared, red and green bands.

# %%
# install tree package for better visualization of folder structure
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 1s (81.2 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree -d
# Out:
# .
# ├── ISPRS_semantic_labeling_Vaihingen
# │   ├── dsm
# │   ├── gts
# │   └── top
# └── logs
#     └── effb0
#         ├── train
#         └── validation
#
# 8 directories

# %% [markdown]
# Reading all images from the _top_, _dsm_ and _gts_ folders

# %%
# Path to the dataset folder in Google Drive
root_path = "ISPRS_semantic_labeling_Vaihingen"
path_top = join(root_path,"top")
path_dsm = join(root_path,"dsm")
path_gts = join(root_path,"gts")

# List with all TIF images in each folder
list_top = glob(join(path_top,"*.tif"))
list_top = natsorted(list_top, key=lambda y: y.lower())

list_dsm = glob(join(path_dsm,"*.tif"))
list_dsm = natsorted(list_dsm, key=lambda y: y.lower())

list_gts = glob(join(path_gts,"*.tif"))
list_gts = natsorted(list_gts, key=lambda y: y.lower())

# %% [markdown]
# ### Train, Validation and Test
# Let's create the train, validation and test sets

# %%
# Images IDs for train and test
train_ids = [1,3,5,7,11,13,15,17,21,23,26,28,30,32,34,37]
test_ids = [2,4,6,8,10,12,14,16,20,22,24,27,29,31,33,35,38]

list_top_train, list_top_val, list_top_test = ([] for i in range(3))
list_dsm_train, list_dsm_val, list_dsm_test = ([] for i in range(3))
list_gts_train, list_gts_val, list_gts_test = ([] for i in range(3))

# %%
for top,dsm,gts in zip(list_top,list_dsm,list_gts):
  # Get the area ID from the filename
  area_id = int(splitext(basename(top))[0].split("area")[-1])
  # Train set
  if area_id in train_ids:    
    list_top_train.append(top)
    list_dsm_train.append(dsm)
    list_gts_train.append(gts)
  # Test set
  elif area_id in test_ids:    
    list_top_test.append(top)
    list_dsm_test.append(dsm)
    list_gts_test.append(gts)

# shuffle train lists
temp = list(zip(list_top_train,list_dsm_train,list_gts_train))
random.seed(10)
random.shuffle(temp)
list_top_train,list_dsm_train,list_gts_train = zip(*temp)

# take 25% as validation set
p_val = 0.25
n_val = int(p_val*len(list_top_train))

list_top_val = list_top_train[:n_val]
list_top_train = list_top_train[n_val:]

list_dsm_val = list_dsm_train[:n_val]
list_dsm_train = list_dsm_train[n_val:]

list_gts_val = list_gts_train[:n_val]
list_gts_train = list_gts_train[n_val:]

# %% [markdown]
# ### Dataset information

# %%
def print_info(list_top,list_dsm,list_gts):
  for top,dsm,gts in zip(list_top,list_dsm,list_gts):
    gt_temp = tifffile.imread(gts)
    n_classes = len(np.unique(gt_temp.reshape(gt_temp.shape[0]*gt_temp.shape[1],-1),axis=0))
    print("TOP:{} , DSM:{} , GT:{} , N:{}".format(basename(top),
                                  basename(dsm),
                                  basename(gts),
                                  n_classes))

# %% [markdown]
# Let's see the number of classes in each image.
#
# **It is very important that all sets have samples of all classes.**

# %%
# Train
print("Train:")
print_info(list_top_train,list_dsm_train,list_gts_train)

# Validation
print("\nValidation:")
print_info(list_top_val,list_dsm_val,list_gts_val)

# Test
print("\nTest:")
print_info(list_top_test,list_dsm_test,list_gts_test)
# Out:
# Train:
# TOP:top_mosaic_09cm_area28.tif , DSM:dsm_09cm_matching_area28.tif , GT:top_mosaic_09cm_area28.tif , N:6
# TOP:top_mosaic_09cm_area37.tif , DSM:dsm_09cm_matching_area37.tif , GT:top_mosaic_09cm_area37.tif , N:5
# TOP:top_mosaic_09cm_area13.tif , DSM:dsm_09cm_matching_area13.tif , GT:top_mosaic_09cm_area13.tif , N:5
# TOP:top_mosaic_09cm_area11.tif , DSM:dsm_09cm_matching_area11.tif , GT:top_mosaic_09cm_area11.tif , N:5
# TOP:top_mosaic_09cm_area30.tif , DSM:dsm_09cm_matching_area30.tif , GT:top_mosaic_09cm_area30.tif , N:5
# TOP:top_mosaic_09cm_area32.tif , DSM:dsm_09cm_matching_area32.tif , GT:top_mosaic_09cm_area32.tif , N:6
# TOP:top_mosaic_09cm_area7.tif , DSM:dsm_09cm_matching_area7.tif , GT:top_mosaic_09cm_area7.tif , N:5
# TOP:top_mosaic_09cm_area1.tif , DSM:dsm_09cm_matching_area1.tif , GT:top_mosaic_09cm_area1.tif , N:6
# TOP:top_mosaic_09cm_area23.tif , DSM:dsm_09cm_matching_area23.tif , GT:top_mosaic_09cm_area23.tif , N:6
# TOP:top_mosaic_09cm_area17.tif , DSM:dsm_09cm_matching_area17.tif , GT:top_mosaic_09cm_area17.tif , N:5
# TOP:top_mosaic_09cm_area15.tif , DSM:dsm_09cm_matching_area15.tif , GT:top_mosaic_09cm_area15.tif , N:6
# TOP:top_mosaic_09cm_area3.tif , DSM:dsm_09cm_matching_area3.tif , GT:top_mosaic_09cm_area3.tif , N:5
#
# Validation:
# TOP:top_mosaic_09cm_area5.tif , DSM:dsm_09cm_matching_area5.tif , GT:top_mosaic_09cm_area5.tif , N:5
# TOP:top_mosaic_09cm_area21.tif , DSM:dsm_09cm_matching_area21.tif , GT:top_mosaic_09cm_area21.tif , N:5
# TOP:top_mosaic_09cm_area34.tif , DSM:dsm_09cm_matching_area34.tif , GT:top_mosaic_09cm_area34.tif , N:5
# TOP:top_mosaic_09cm_area26.tif , DSM:dsm_09cm_matching_area26.tif , GT:top_mosaic_09cm_area26.tif , N:6
#
# Test:
# TOP:top_mosaic_09cm_area2.tif , DSM:dsm_09cm_matching_area2.tif , GT:top_mosaic_09cm_area2.tif , N:6
# TOP:top_mosaic_09cm_area4.tif , DSM:dsm_09cm_matching_area4.tif , GT:top_mosaic_09cm_area4.tif , N:5
# TOP:top_mosaic_09cm_area6.tif , DSM:dsm_09cm_matching_area6.tif , GT:top_mosaic_09cm_area6.tif , N:5
# TOP:top_mosaic_09cm_area8.tif , DSM:dsm_09cm_matching_area8.tif , GT:top_mosaic_09cm_area8.tif , N:5
# TOP:top_mosaic_09cm_area10.tif , DSM:dsm_09cm_matching_area10.tif , GT:top_mosaic_09cm_area10.tif , N:5
# TOP:top_mosaic_09cm_area12.tif , DSM:dsm_09cm_matching_area12.tif , GT:top_mosaic_09cm_area12.tif , N:5
# TOP:top_mosaic_09cm_area14.tif , DSM:dsm_09cm_matching_area14.tif , GT:top_mosaic_09cm_area14.tif , N:5
# TOP:top_mosaic_09cm_area16.tif , DSM:dsm_09cm_matching_area16.tif , GT:top_mosaic_09cm_area16.tif , N:5
# TOP:top_mosaic_09cm_area20.tif , DSM:dsm_09cm_matching_area20.tif , GT:top_mosaic_09cm_area20.tif , N:6
# TOP:top_mosaic_09cm_area22.tif , DSM:dsm_09cm_matching_area22.tif , GT:top_mosaic_09cm_area22.tif , N:5
# TOP:top_mosaic_09cm_area24.tif , DSM:dsm_09cm_matching_area24.tif , GT:top_mosaic_09cm_area24.tif , N:5
# TOP:top_mosaic_09cm_area27.tif , DSM:dsm_09cm_matching_area27.tif , GT:top_mosaic_09cm_area27.tif , N:6
# TOP:top_mosaic_09cm_area29.tif , DSM:dsm_09cm_matching_area29.tif , GT:top_mosaic_09cm_area29.tif , N:6
# TOP:top_mosaic_09cm_area31.tif , DSM:dsm_09cm_matching_area31.tif , GT:top_mosaic_09cm_area31.tif , N:6
# TOP:top_mosaic_09cm_area33.tif , DSM:dsm_09cm_matching_area33.tif , GT:top_mosaic_09cm_area33.tif , N:6
# TOP:top_mosaic_09cm_area35.tif , DSM:dsm_09cm_matching_area35.tif , GT:top_mosaic_09cm_area35.tif , N:5
# TOP:top_mosaic_09cm_area38.tif , DSM:dsm_09cm_matching_area38.tif , GT:top_mosaic_09cm_area38.tif , N:5

# %% [markdown]
# ### Visualization of dataset samples

# %%
#@title Samples Visualization { run: "auto"}
#@markdown Select a sample
id_sample = 28 #@param {type:"slider", min:0, max:32, step:1}
img_top = tifffile.imread(list_top[id_sample])
img_dsm = tifffile.imread(list_dsm[id_sample])

print("Image: {}".format(list_top[id_sample]))

plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.imshow(img_top)
plt.title("RGB False Color composition\n{}\
          \nMin:{}, Max:{}".format(img_top.shape,
                                     img_top.min(),
                                     img_top.max()))
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(img_dsm, cmap="gray")
plt.title("Digital Surface Model\
            \nMin:{:.2f}, Max:{:.2f}".format(img_dsm.min(),
                                             img_dsm.max()))
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(tifffile.imread(list_gts[id_sample]))
plt.title("Ground Truth")
plt.axis("off")

g = plt.subplot(1,4,4)
g.axes.set_xlim(0,3.4)
g.axes.set_ylim(-0.01,0.55)

g.text(0, 0.025, "Impervious surfaces")
g.text(0, 0.125, "Building ")
g.text(0, 0.225, "Low vegetation")
g.text(0, 0.325, "Tree ")
g.text(0, 0.425, "Car ")
g.text(0, 0.525, "Clutter/background")

x_rec = 2.3
g.add_patch(patches.Rectangle((x_rec,0.0), 1, 0.05, facecolor="#FFFFFF", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.1), 1, 0.05, facecolor="#0000FF", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.2), 1, 0.05, facecolor="#00FFFF", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.3), 1, 0.05, facecolor="#00FF00", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.4), 1, 0.05, facecolor="#FFFF00", edgecolor="black"))
g.add_patch(patches.Rectangle((x_rec,0.5), 1, 0.05, facecolor="#FF0000", edgecolor="black"))
g.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Image: ISPRS_semantic_labeling_Vaihingen/top/top_mosaic_09cm_area33.tif

# %% [markdown]
# ### Classes
# Dictionary to represent each color and its corresponding class.

# %%
color2index = {(255,255,255) : 0,
               (0  ,0  ,255) : 1,
               (0  ,255,255) : 2,
               (0  ,255,0  ) : 3,
               (255,255,0  ) : 4,
               (255,0  ,0  ) : 5
               }
n_classes = len(color2index)

# %% [markdown]
# ## Data Generator

# %% [markdown]
# Requirements of the model:
#
# - **Input:** Image $[height×width×bands]$
# - **Output:** Image $[height×width×classes]$
#
# As the images are too big, we will extract patches with a size $[p×p]$ and step (stride) $s$.
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1UYrpG-sD_UGCRR7Ras73THF-sbqQoGTu" width=100 img>
# </center>
#
#
# Data Generator parameters:
# - _batch_size_: number of samples per batch
# - _patch_size_: size of the patch extracted from the image
# - _step_size_: step to extract patches from the image
# - _list_top_: list with paths of RGB images
# - _list_dsm_: list with paths of DSM images
# - _list_gts_: list with paths of GT images
# - _n_classes_: number of classes
# - _colormap_gt_: dictionary with the colormap to convert RGB image $[H×W×3]$ to label image $[H×W×1]$
#
# **Recommendation:** Use [Pillow](https://pillow.readthedocs.io/en/stable/) to reduce processing time in reading and cropping the image, because it just loads the part of the image specified by the method [crop](https://pillow.readthedocs.io/en/stable/reference/ImageOps.html?highlight=crop#PIL.ImageOps.crop) when it is converted to a numpy array (_np.asarray_).
#
# ```python
# # Just reading the header of the image with its information
# data = Image.open(path)
# # Cropping the area of the image
# data = data.crop((x, y, x+patch_size, y+patch_size)
# # Loads only the cropped area of the image
# data = np.asarray(data)
# ```

# %%
class DataGenerator(keras.utils.Sequence):
  def __init__(self,
               batch_size,
               patch_size,
               step_size,
               list_top,                
               list_gts,
               n_classes,
               colormap_gt=None,
               augmentation=None,
               preprocessing=None,               
               shuffle=True):
    self.batch_size = batch_size
    self.patch_size = patch_size
    self.step_size = step_size
    self.list_top = list_top    
    self.list_gts = list_gts
    self.n_classes = n_classes
    self.colormap_gt = colormap_gt
    self.augmentation = augmentation
    self.preprocessing = preprocessing        
    self.shuffle= shuffle
    self.path_coords = self.__get_path_coords()
    self.n_patchs = len(self.path_coords)

  def __get_path_coords(self):
    path_coords = []    
    for path_image, path_label in zip(self.list_top,self.list_gts):       
      width, height = Image.open(path_label).size      
      for y in range(0, height, self.step_size):
        for x in range(0, width, self.step_size):
          if (x + self.patch_size) > width:
            x = width - self.patch_size
          if (y + self.patch_size) > height:
            y = height - self.patch_size
          
          path_coords.append((path_image, path_label, (x,y)))          
    return path_coords
        
  def on_epoch_end(self):
    if self.shuffle:
      random.shuffle(self.path_coords)

  def __len__(self):
    return np.ceil(self.n_patchs/self.batch_size).astype("int")

  def __get_patch_image(self, path_image, x, y):
    # Reading the RGB image
    data_image = Image.open(path_image)
    data_image = data_image.crop((x, y, 
                                  x + self.patch_size, y + self.patch_size))
    data_image = np.asarray(data_image).astype("float32")
    
    return data_image/255.0

  def __get_patch_mask(self, path, x, y):
    # Reading the mask
    data_mask = Image.open(path)
    data_mask = data_mask.crop((x, y, 
                                x + self.patch_size, y + self.patch_size))
    data_mask = np.asarray(data_mask)
    # Convert RGB image [H x W x 3] to label image [H x W x 1]
    data_mask_idx = np.zeros((data_mask.shape[0], 
                              data_mask.shape[1]), dtype=np.uint8)
    for key in self.colormap_gt:
      class_id = self.colormap_gt[key]
      key = np.array(key)
      # Assign an index to each color based on the colormap
      # (255,255,255) : 0
      # (0  ,0  ,255) : 1,...
      data_mask_idx[(data_mask[:,:,0] == key[0]) & 
                    (data_mask[:,:,1] == key[1]) & 
                    (data_mask[:,:,2] == key[2])] = class_id
    return data_mask_idx

  def __getitem__(self, idx):
    i = idx * self.batch_size
    
    current_batch_size = self.batch_size
    if (idx+1) == self.__len__():
      current_batch_size = len(self.path_coords[i:])

    # Batch of coordinates
    batch_path_coords = self.path_coords[i : i + current_batch_size]

    x = np.zeros((current_batch_size, 
                  self.patch_size, 
                  self.patch_size, 
                  3),
                  dtype=np.float32)

    y = np.zeros((current_batch_size,
                  self.patch_size, 
                  self.patch_size,
                  self.n_classes),
                  dtype=np.float32)

    for j, (path_image, path_label, (x_pos, y_pos)) in enumerate(batch_path_coords):
      # Get an individual image and its corresponding label
      x_sample = self.__get_patch_image(path_image, x_pos, y_pos)
      y_sample = self.__get_patch_mask(path_label, x_pos, y_pos)        
      
      # If there are augmentation transformations, apply them
      if self.augmentation is not None:
        augmented = self.augmentation()(image=x_sample, mask=y_sample)
        x_sample = augmented["image"]
        y_sample = augmented["mask"]
      # If there is a preprocessing function, apply it
      if self.preprocessing is not None:
        preprocessed = self.preprocessing(image=x_sample, mask=y_sample)
        x_sample = preprocessed['image']
        y_sample = preprocessed['mask']
      # Convert labels to one hot encoding
      y_sample = to_categorical(y_sample, self.n_classes)

      x[j,...] = x_sample
      y[j,...] = y_sample
    return x, y

# %% [markdown]
# Create a temporal generator just to verify the output of our class DataGenerator and visualize a batch.

# %%
# Temporal generator
temp_generator = DataGenerator(batch_size=4,
                         patch_size=256,
                         step_size=256,
                         list_top=list_top_train, 
                         list_gts=list_gts_train,
                         n_classes=n_classes,
                         colormap_gt=color2index
                         )
# Iterate over all batches
for x,y in temp_generator:
  # Check the shape of the output of the generator
  print(x.shape, y.shape)
  for x_i,y_i in zip(x,y):
    # For visualization: [0,1] => [0,255]
    x_i = x_i*255
    # Apply argmax to convert from one hot to integers
    y_i = np.argmax(y_i, axis=-1)
    # Convert each class to a color given a colormap
    y_i_rgb = np.zeros((y_i.shape[0], y_i.shape[1], 3), dtype=np.uint8)
    for key,value in color2index.items():
      y_i_rgb[y_i==value] = key      
    # Visualization of RGB image and its ground truth or reference
    plt.figure(figsize=(10,10))
    plt.subplot(1,2,1)
    plt.imshow(x_i.astype("uint8"))
    plt.title("RGB Image")
    plt.axis("off")

    plt.subplot(1,2,2)
    plt.imshow(y_i_rgb, cmap="jet")
    plt.title("Ground Truth")
    plt.axis("off")
    plt.show()
  break
# Out:
# (4, 256, 256, 3) (4, 256, 256, 6)

# %% [markdown]
# ### DataGenerator for train and validation

# %% [markdown]
# Let's create the generators for training and validation:
# - $batch\_size=8$
# - $patch\_size=256$
# - $step\_size=256$

# %%
batch_size = 8
patch_size = 256
step_size = 256

data_gen_train = DataGenerator(batch_size=batch_size,
                               patch_size=patch_size,
                               step_size=step_size,
                               list_top=list_top_train, 
                               list_gts=list_gts_train,
                               n_classes=n_classes,
                               colormap_gt=color2index
                               )

data_gen_val = DataGenerator(batch_size=batch_size,
                             patch_size=patch_size,
                             step_size=step_size,
                             list_top=list_top_val, 
                             list_gts=list_gts_val,
                             n_classes=n_classes,
                             colormap_gt=color2index
                             )

# %% [markdown]
# Number of batches in each set:

# %%
print("Train: {}, Validation: {}".format(len(data_gen_train), len(data_gen_val)))
# Out:
# Train: 128, Validation: 38

# %% [markdown]
# ## Semantic Segmentation models
# We will use the U-Net model for multiclass semantic segmentation.
#
# <center>
# <img width=700 src="https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png" img>
# </center>
#
# Code based on [U-Net image segmentation in Keras](https://pyimagesearch.com/2022/02/21/u-net-image-segmentation-in-keras/)

# %% [markdown]
# Functions with block to build a U-Net:
# - _conv_block_: convolutional block with only multiple convolutions.
# - _downsampling_: downsampling block with a series of convolutions, a max pooling and dropout layers.
# - _upsampling_: upsampling block with a transpose convolution, concatenate a feature map, dropout and a series of convolutions.
#
# the combination of upsampling and the convolution, if applied well, equals the effect of the transposed convolution. This hence allows us to reconstruct the image into its original size, presumably without losing a lot of details (which would have happened with upsampling alone, if such reconstruction would have been possible at all).

# %%
def conv_block(x, n_filters, times=2):
  for i in range(times):
    x = Conv2D(filters=n_filters, 
              kernel_size=3, 
              strides=1, 
              padding="same", 
              activation="relu", 
              kernel_initializer="he_normal")(x)
  return x

def downsampling(x, n_filters, times=2):
  feat = conv_block(x, n_filters, times=times)  
  pool = MaxPooling2D(pool_size=2)(feat)
  pool = Dropout(rate=0.3)(pool)
  return feat,pool

def upsampling(input, filters, layer_concat=None):
  x = Conv2DTranspose(filters=filters, 
                      kernel_size=3, 
                      strides=2, 
                      padding="same")(input)
  if layer_concat is not None:
    x = concatenate([x, layer_concat])
  x = Dropout(rate=0.3)(x)  
  x = conv_block(x, filters, times=2)
  return x

    
def upsampling_nearest(input, filters, layer_concat=None):
  x = UpSampling2D(size=(2, 2),
              interpolation="nearest")(input)
  
  if layer_concat is not None:
    x = concatenate([x, layer_concat])
  x = Dropout(rate=0.3)(x)  
  x = conv_block(x, filters, times=2)
  return x    

def upsampling_bilinear(input, filters, layer_concat=None):
  x = UpSampling2D(size=(2, 2),
              interpolation="bilinear")(input)
  
  if layer_concat is not None:
    x = concatenate([x, layer_concat])
  x = Dropout(rate=0.3)(x)  
  x = conv_block(x, filters, times=2)
  return x

# %% [markdown]
# Building the U-Net model.
#
# _Notice that the original model has a bottleneck area with **1024** features, we are only using **512** for this example._

# %% [markdown]
# Building the U-Net model with "Transpose Conv Layers"

# %%
def get_unet_transpose_conv(img_size, n_classes):
  # Input
  input = Input(shape=(img_size,img_size,3))
  # Downsampling
  f1,p1 = downsampling(input, 64, times=2)
  f2,p2 = downsampling(p1, 128, times=2)
  f3,p3 = downsampling(p2, 256, times=2)
  # Bottleneck
  blottleneck = conv_block(p3, 512, times=2)
  #Upsampling  
  u7 = upsampling(blottleneck, 256, layer_concat=f3)
  u8 = upsampling(u7, 128, layer_concat=f2)
  u9 = upsampling(u8, 64, layer_concat=f1)
  # Output
  output = Conv2D(filters=n_classes, 
                  kernel_size=1, 
                  padding="same", 
                  activation="softmax")(u9)
  model = Model(inputs=input, outputs=output, name="UNet")

  return model

# %% [markdown]
# Building the U-Net model with "Unpooling with Nearest Neighbor"

# %%
def get_unet_nearest_neighbor(img_size, n_classes):
  # Input
  input = Input(shape=(img_size,img_size,3))
  # Downsampling
  f1,p1 = downsampling(input, 64, times=2)
  f2,p2 = downsampling(p1, 128, times=2)
  f3,p3 = downsampling(p2, 256, times=2)
  # Bottleneck
  blottleneck = conv_block(p3, 512, times=2)
  #Upsampling  
  u7 = upsampling_nearest(blottleneck, 256, layer_concat=f3)
  u8 = upsampling_nearest(u7, 128, layer_concat=f2)
  u9 = upsampling_nearest(u8, 64, layer_concat=f1)
  # Output
  output = Conv2D(filters=n_classes, 
                  kernel_size=1, 
                  padding="same", 
                  activation="softmax")(u9)
  model = Model(inputs=input, outputs=output, name="UNet")

  return model

# %% [markdown]
# Building the U-Net model with "Unpooling with Bed of Nails"

# %%
def get_unet_bilinear(img_size, n_classes):
  # Input
  input = Input(shape=(img_size,img_size,3))
  # Downsampling
  f1,p1 = downsampling(input, 64, times=2)
  f2,p2 = downsampling(p1, 128, times=2)
  f3,p3 = downsampling(p2, 256, times=2)
  # Bottleneck
  blottleneck = conv_block(p3, 512, times=2)
  #Upsampling  
  u7 = upsampling_bilinear(blottleneck, 256, layer_concat=f3)
  u8 = upsampling_bilinear(u7, 128, layer_concat=f2)
  u9 = upsampling_bilinear(u8, 64, layer_concat=f1)
  # Output
  output = Conv2D(filters=n_classes, 
                  kernel_size=1, 
                  padding="same", 
                  activation="softmax")(u9)
  model = Model(inputs=input, outputs=output, name="UNet")

  return model

# %% [markdown]
# Building the U-Net models

# %%
model_unet_transpose_conv = get_unet_transpose_conv(img_size=patch_size, 
                    n_classes=n_classes)
model_unet_nearest_neighbor = get_unet_nearest_neighbor(img_size=patch_size, 
                    n_classes=n_classes)
model_unet_bilinear = get_unet_bilinear(img_size=patch_size, 
                    n_classes=n_classes)

# %% [markdown]
# ### Visualization of U-Net

# %%
model_unet_transpose_conv.summary()
model_unet_nearest_neighbor.summary()
model_unet_bilinear.summary()
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['dropout[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 128)  0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 256)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_6[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 256)  1179904    ['conv2d_7[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 512)  0           ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 256)  1179904     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_8[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 12  295040     ['conv2d_9[0][0]']
#  spose)                         8)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_1[0][0]',
#                                 6)                                'conv2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 128, 128, 25  0           ['concatenate_1[0][0]']
#                                 6)
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 12  295040      ['dropout_4[0][0]']
#                                 8)
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_10[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 64  73792      ['conv2d_11[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 256, 256, 12  0           ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 64  73792       ['dropout_5[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 6)  390         ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 8,557,830
# Trainable params: 8,557,830
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  1792        ['input_2[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_15[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_16[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 128, 128, 64  0           ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 12  73856       ['dropout_6[0][0]']
#                                 8)
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_17[0][0]']
#                                 8)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_18[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 128)  0           ['max_pooling2d_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 256)  295168      ['dropout_7[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_19[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_20[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 32, 256)  0           ['max_pooling2d_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 512)  1180160     ['dropout_8[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_21[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 512)  0           ['conv2d_22[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  dropout_9 (Dropout)            (None, 64, 64, 768)  0           ['concatenate_3[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 256)  1769728     ['dropout_9[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_23[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_24[0][0]']
#                                 6)
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'conv2d_18[0][0]']
#
#  dropout_10 (Dropout)           (None, 128, 128, 38  0           ['concatenate_4[0][0]']
#                                 4)
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 12  442496      ['dropout_10[0][0]']
#                                 8)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_25[0][0]']
#                                 8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_26[0][0]']
#                                 8)
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'conv2d_16[0][0]']
#
#  dropout_11 (Dropout)           (None, 256, 256, 19  0           ['concatenate_5[0][0]']
#                                 2)
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 64  110656      ['dropout_11[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_27[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 6)  390         ['conv2d_28[0][0]']
#
# ==================================================================================================
# Total params: 7,783,238
# Trainable params: 7,783,238
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_30 (Conv2D)             (None, 256, 256, 64  1792        ['input_3[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_30[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_31[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 128, 128, 64  0           ['max_pooling2d_6[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 12  73856       ['dropout_12[0][0]']
#                                 8)
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_32[0][0]']
#                                 8)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_33[0][0]']
#
#  dropout_13 (Dropout)           (None, 64, 64, 128)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 256)  295168      ['dropout_13[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_34[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_35[0][0]']
#
#  dropout_14 (Dropout)           (None, 32, 32, 256)  0           ['max_pooling2d_8[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 512)  1180160     ['dropout_14[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_36[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 512)  0          ['conv2d_37[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 768)  0           ['up_sampling2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  dropout_15 (Dropout)           (None, 64, 64, 768)  0           ['concatenate_6[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 256)  1769728     ['dropout_15[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_38[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 25  0          ['conv2d_39[0][0]']
#                                 6)
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 38  0           ['up_sampling2d_4[0][0]',
#                                 4)                                'conv2d_33[0][0]']
#
#  dropout_16 (Dropout)           (None, 128, 128, 38  0           ['concatenate_7[0][0]']
#                                 4)
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 12  442496      ['dropout_16[0][0]']
#                                 8)
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_40[0][0]']
#                                 8)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 12  0          ['conv2d_41[0][0]']
#                                 8)
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 19  0           ['up_sampling2d_5[0][0]',
#                                 2)                                'conv2d_31[0][0]']
#
#  dropout_17 (Dropout)           (None, 256, 256, 19  0           ['concatenate_8[0][0]']
#                                 2)
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 64  110656      ['dropout_17[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_42[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 6)  390         ['conv2d_43[0][0]']
#
# ==================================================================================================
# Total params: 7,783,238
# Trainable params: 7,783,238
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_unet_transpose_conv, to_file="model_unet_2.png", show_shapes=True)

# %%
plot_model(model_unet_bilinear, to_file="model_unet_3.png", show_shapes=True)

# %% [markdown]
# ### Training configuration

# %% [markdown]
# We will use _Intersection over Union (IoU)_ as metric to be monitored during training.
#
# As the labels are in _one hot_ encoding, we can use the _one hot_ version of _mean IoU_: [OneHotMeanIoU](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/OneHotMeanIoU).
#
# Also, to assess the model, we will compute the IoU per class in the test set, so we can use: [OneHotIoU](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/OneHotIoU) per class.

# %%
model_unet_transpose_conv.compile(optimizer=Adam(),
                  loss="categorical_crossentropy",
                  metrics=["accuracy", OneHotMeanIoU(num_classes=n_classes, name="iou")])

# %%
model_unet_nearest_neighbor.compile(optimizer=Adam(),
                  loss="categorical_crossentropy",
                  metrics=["accuracy", OneHotMeanIoU(num_classes=n_classes, name="iou")])

# %%
model_unet_bilinear.compile(optimizer=Adam(),
                  loss="categorical_crossentropy",
                  metrics=["accuracy", OneHotMeanIoU(num_classes=n_classes, name="iou")])

# %% [markdown]
# ### Callbacks

# %% [markdown]
# Function to save checkpoints for each model

# %%
def get_ckpt(ckpt_name):
    return ModelCheckpoint(ckpt_name,
                           mode="max", 
                           save_best_only=True, 
                           monitor="val_iou", 
                           verbose=1)

# %% [markdown]
# Callbacks definition to be executed during training

# %%
# Callbacks
# Checkpoint
autosave_unet_transpose_conv = get_ckpt("segmentation_unet_transpose_conv.h5")
autosave_unet_nearest_neighbor = get_ckpt("segmentation_unet_nearest_neighbor.h5")
autosave_unet_bilinear = get_ckpt("segmentation_unet_bilinear.h5")

# Early stopping
early_stopping = EarlyStopping(patience=30, verbose=1, mode = 'auto')

cbks_unet_transpose_conv = [autosave_unet_transpose_conv, early_stopping]
cbks_unet_nearest_neighbor = [autosave_unet_nearest_neighbor, early_stopping]
cbks_unet_bilinear = [autosave_unet_bilinear, early_stopping]

# %%
epochs = 200

# %% [markdown]
# ### Training

# %%
history_unet_transpose_conv = model_unet_transpose_conv.fit(data_gen_train,
                              epochs=epochs,                                                     
                              validation_data=data_gen_val,                                                    
                              callbacks=cbks_unet_transpose_conv,
                              workers=4, 
                              use_multiprocessing=True,
                              max_queue_size=20
                              )
# Out:
# Epoch 1/200
# 128/128 [==============================] - ETA: 0s - loss: 1.0236 - accuracy: 0.5356 - iou: 0.2459
# Epoch 1: val_iou improved from -inf to 0.30769, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 118s 730ms/step - loss: 1.0236 - accuracy: 0.5356 - iou: 0.2459 - val_loss: 0.9490 - val_accuracy: 0.6285 - val_iou: 0.3077
# Epoch 2/200
# 128/128 [==============================] - ETA: 0s - loss: 0.8395 - accuracy: 0.6456 - iou: 0.3201
# Epoch 2: val_iou improved from 0.30769 to 0.34491, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 100s 765ms/step - loss: 0.8395 - accuracy: 0.6456 - iou: 0.3201 - val_loss: 0.8881 - val_accuracy: 0.6733 - val_iou: 0.3449
# Epoch 3/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7878 - accuracy: 0.6733 - iou: 0.3434
# Epoch 3: val_iou improved from 0.34491 to 0.35518, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 116s 893ms/step - loss: 0.7878 - accuracy: 0.6733 - iou: 0.3434 - val_loss: 0.8512 - val_accuracy: 0.6827 - val_iou: 0.3552
# Epoch 4/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7492 - accuracy: 0.6903 - iou: 0.3586
# Epoch 4: val_iou improved from 0.35518 to 0.39424, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 103s 789ms/step - loss: 0.7492 - accuracy: 0.6903 - iou: 0.3586 - val_loss: 0.7942 - val_accuracy: 0.7337 - val_iou: 0.3942
# Epoch 5/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7223 - accuracy: 0.7008 - iou: 0.3687
# Epoch 5: val_iou did not improve from 0.39424
# 128/128 [==============================] - 113s 865ms/step - loss: 0.7223 - accuracy: 0.7008 - iou: 0.3687 - val_loss: 0.7808 - val_accuracy: 0.7205 - val_iou: 0.3814
# Epoch 6/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7155 - accuracy: 0.7041 - iou: 0.3721
# Epoch 6: val_iou did not improve from 0.39424
# 128/128 [==============================] - 112s 861ms/step - loss: 0.7155 - accuracy: 0.7041 - iou: 0.3721 - val_loss: 0.7980 - val_accuracy: 0.7054 - val_iou: 0.3687
# Epoch 7/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.7027 - iou: 0.3715
# Epoch 7: val_iou did not improve from 0.39424
# 128/128 [==============================] - 114s 873ms/step - loss: 0.7134 - accuracy: 0.7027 - iou: 0.3715 - val_loss: 0.7887 - val_accuracy: 0.7201 - val_iou: 0.3844
# Epoch 8/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6982 - accuracy: 0.7099 - iou: 0.3777
# Epoch 8: val_iou improved from 0.39424 to 0.39846, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 116s 889ms/step - loss: 0.6982 - accuracy: 0.7099 - iou: 0.3777 - val_loss: 0.7872 - val_accuracy: 0.7382 - val_iou: 0.3985
# Epoch 9/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6855 - accuracy: 0.7200 - iou: 0.3879
# Epoch 9: val_iou did not improve from 0.39846
# 128/128 [==============================] - 101s 773ms/step - loss: 0.6855 - accuracy: 0.7200 - iou: 0.3879 - val_loss: 0.7890 - val_accuracy: 0.7230 - val_iou: 0.3856
# Epoch 10/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.7154 - iou: 0.3841
# Epoch 10: val_iou did not improve from 0.39846
# 128/128 [==============================] - 101s 773ms/step - loss: 0.6909 - accuracy: 0.7154 - iou: 0.3841 - val_loss: 0.7835 - val_accuracy: 0.7362 - val_iou: 0.3959
# Epoch 11/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.7172 - iou: 0.3878
# Epoch 11: val_iou improved from 0.39846 to 0.40710, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 102s 780ms/step - loss: 0.6865 - accuracy: 0.7172 - iou: 0.3878 - val_loss: 0.7224 - val_accuracy: 0.7533 - val_iou: 0.4071
# Epoch 12/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.7224 - iou: 0.4006
# Epoch 12: val_iou did not improve from 0.40710
# 128/128 [==============================] - 114s 874ms/step - loss: 0.6706 - accuracy: 0.7224 - iou: 0.4006 - val_loss: 0.7613 - val_accuracy: 0.7325 - val_iou: 0.3957
# Epoch 13/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.7233 - iou: 0.3982
# Epoch 13: val_iou did not improve from 0.40710
# 128/128 [==============================] - 113s 870ms/step - loss: 0.6757 - accuracy: 0.7233 - iou: 0.3982 - val_loss: 0.7780 - val_accuracy: 0.7275 - val_iou: 0.4041
# Epoch 14/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.7253 - iou: 0.4046
# Epoch 14: val_iou improved from 0.40710 to 0.40862, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 102s 781ms/step - loss: 0.6663 - accuracy: 0.7253 - iou: 0.4046 - val_loss: 0.7414 - val_accuracy: 0.7481 - val_iou: 0.4086
# Epoch 15/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6614 - accuracy: 0.7281 - iou: 0.3995
# Epoch 15: val_iou improved from 0.40862 to 0.41079, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 100s 763ms/step - loss: 0.6614 - accuracy: 0.7281 - iou: 0.3995 - val_loss: 0.7431 - val_accuracy: 0.7402 - val_iou: 0.4108
# Epoch 16/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6653 - accuracy: 0.7277 - iou: 0.4085
# Epoch 16: val_iou did not improve from 0.41079
# 128/128 [==============================] - 100s 765ms/step - loss: 0.6653 - accuracy: 0.7277 - iou: 0.4085 - val_loss: 0.8088 - val_accuracy: 0.7098 - val_iou: 0.3754
# Epoch 17/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6601 - accuracy: 0.7294 - iou: 0.4092
# Epoch 17: val_iou did not improve from 0.41079
# 128/128 [==============================] - 112s 861ms/step - loss: 0.6601 - accuracy: 0.7294 - iou: 0.4092 - val_loss: 0.7477 - val_accuracy: 0.7381 - val_iou: 0.4028
# Epoch 18/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.7352 - iou: 0.4125
# Epoch 18: val_iou improved from 0.41079 to 0.41129, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 115s 879ms/step - loss: 0.6487 - accuracy: 0.7352 - iou: 0.4125 - val_loss: 0.7312 - val_accuracy: 0.7557 - val_iou: 0.4113
# Epoch 19/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6586 - accuracy: 0.7310 - iou: 0.4032
# Epoch 19: val_iou improved from 0.41129 to 0.43016, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 101s 771ms/step - loss: 0.6586 - accuracy: 0.7310 - iou: 0.4032 - val_loss: 0.7068 - val_accuracy: 0.7587 - val_iou: 0.4302
# Epoch 20/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6517 - accuracy: 0.7337 - iou: 0.4231
# Epoch 20: val_iou did not improve from 0.43016
# 128/128 [==============================] - 99s 755ms/step - loss: 0.6517 - accuracy: 0.7337 - iou: 0.4231 - val_loss: 0.7370 - val_accuracy: 0.7432 - val_iou: 0.4153
# Epoch 21/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6496 - accuracy: 0.7355 - iou: 0.4107
# Epoch 21: val_iou did not improve from 0.43016
# 128/128 [==============================] - 115s 879ms/step - loss: 0.6496 - accuracy: 0.7355 - iou: 0.4107 - val_loss: 0.7363 - val_accuracy: 0.7500 - val_iou: 0.4181
# Epoch 22/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.7363 - iou: 0.4182
# Epoch 22: val_iou did not improve from 0.43016
# 128/128 [==============================] - 99s 760ms/step - loss: 0.6469 - accuracy: 0.7363 - iou: 0.4182 - val_loss: 0.7190 - val_accuracy: 0.7538 - val_iou: 0.4140
# Epoch 23/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6327 - accuracy: 0.7417 - iou: 0.4205
# Epoch 23: val_iou did not improve from 0.43016
# 128/128 [==============================] - 97s 744ms/step - loss: 0.6327 - accuracy: 0.7417 - iou: 0.4205 - val_loss: 0.7322 - val_accuracy: 0.7506 - val_iou: 0.4199
# Epoch 24/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6350 - accuracy: 0.7415 - iou: 0.4329
# Epoch 24: val_iou improved from 0.43016 to 0.43314, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 116s 888ms/step - loss: 0.6350 - accuracy: 0.7415 - iou: 0.4329 - val_loss: 0.6933 - val_accuracy: 0.7658 - val_iou: 0.4331
# Epoch 25/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6264 - accuracy: 0.7449 - iou: 0.4240
# Epoch 25: val_iou did not improve from 0.43314
# 128/128 [==============================] - 99s 756ms/step - loss: 0.6264 - accuracy: 0.7449 - iou: 0.4240 - val_loss: 0.7247 - val_accuracy: 0.7563 - val_iou: 0.4312
# Epoch 26/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.7407 - iou: 0.4270
# Epoch 26: val_iou did not improve from 0.43314
# 128/128 [==============================] - 99s 759ms/step - loss: 0.6366 - accuracy: 0.7407 - iou: 0.4270 - val_loss: 0.7075 - val_accuracy: 0.7534 - val_iou: 0.4239
# Epoch 27/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6204 - accuracy: 0.7471 - iou: 0.4324
# Epoch 27: val_iou improved from 0.43314 to 0.43649, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 115s 883ms/step - loss: 0.6204 - accuracy: 0.7471 - iou: 0.4324 - val_loss: 0.7112 - val_accuracy: 0.7627 - val_iou: 0.4365
# Epoch 28/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7463 - iou: 0.4391
# Epoch 28: val_iou did not improve from 0.43649
# 128/128 [==============================] - 113s 866ms/step - loss: 0.6223 - accuracy: 0.7463 - iou: 0.4391 - val_loss: 0.7726 - val_accuracy: 0.7326 - val_iou: 0.4078
# Epoch 29/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6205 - accuracy: 0.7477 - iou: 0.4410
# Epoch 29: val_iou did not improve from 0.43649
# 128/128 [==============================] - 97s 741ms/step - loss: 0.6205 - accuracy: 0.7477 - iou: 0.4410 - val_loss: 0.7618 - val_accuracy: 0.7332 - val_iou: 0.4049
# Epoch 30/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7454 - iou: 0.4344
# Epoch 30: val_iou did not improve from 0.43649
# 128/128 [==============================] - 113s 865ms/step - loss: 0.6223 - accuracy: 0.7454 - iou: 0.4344 - val_loss: 0.7058 - val_accuracy: 0.7626 - val_iou: 0.4343
# Epoch 31/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6132 - accuracy: 0.7516 - iou: 0.4433
# Epoch 31: val_iou did not improve from 0.43649
# 128/128 [==============================] - 114s 870ms/step - loss: 0.6132 - accuracy: 0.7516 - iou: 0.4433 - val_loss: 0.7494 - val_accuracy: 0.7375 - val_iou: 0.4114
# Epoch 32/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6134 - accuracy: 0.7505 - iou: 0.4411
# Epoch 32: val_iou did not improve from 0.43649
# 128/128 [==============================] - 99s 753ms/step - loss: 0.6134 - accuracy: 0.7505 - iou: 0.4411 - val_loss: 0.7093 - val_accuracy: 0.7626 - val_iou: 0.4240
# Epoch 33/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6150 - accuracy: 0.7506 - iou: 0.4463
# Epoch 33: val_iou did not improve from 0.43649
# 128/128 [==============================] - 97s 744ms/step - loss: 0.6150 - accuracy: 0.7506 - iou: 0.4463 - val_loss: 0.7457 - val_accuracy: 0.7465 - val_iou: 0.4146
# Epoch 34/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6063 - accuracy: 0.7524 - iou: 0.4495
# Epoch 34: val_iou did not improve from 0.43649
# 128/128 [==============================] - 99s 755ms/step - loss: 0.6063 - accuracy: 0.7524 - iou: 0.4495 - val_loss: 0.7130 - val_accuracy: 0.7503 - val_iou: 0.4138
# Epoch 35/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5988 - accuracy: 0.7564 - iou: 0.4447
# Epoch 35: val_iou improved from 0.43649 to 0.44806, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 101s 773ms/step - loss: 0.5988 - accuracy: 0.7564 - iou: 0.4447 - val_loss: 0.6905 - val_accuracy: 0.7708 - val_iou: 0.4481
# Epoch 36/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6028 - accuracy: 0.7537 - iou: 0.4553
# Epoch 36: val_iou did not improve from 0.44806
# 128/128 [==============================] - 98s 746ms/step - loss: 0.6028 - accuracy: 0.7537 - iou: 0.4553 - val_loss: 0.7297 - val_accuracy: 0.7480 - val_iou: 0.4277
# Epoch 37/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.7575 - iou: 0.4545
# Epoch 37: val_iou did not improve from 0.44806
# 128/128 [==============================] - 113s 868ms/step - loss: 0.5991 - accuracy: 0.7575 - iou: 0.4545 - val_loss: 0.7349 - val_accuracy: 0.7512 - val_iou: 0.4198
# Epoch 38/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.7619 - iou: 0.4551
# Epoch 38: val_iou did not improve from 0.44806
# 128/128 [==============================] - 100s 763ms/step - loss: 0.5880 - accuracy: 0.7619 - iou: 0.4551 - val_loss: 0.7513 - val_accuracy: 0.7417 - val_iou: 0.4088
# Epoch 39/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5973 - accuracy: 0.7578 - iou: 0.4537
# Epoch 39: val_iou did not improve from 0.44806
# 128/128 [==============================] - 112s 857ms/step - loss: 0.5973 - accuracy: 0.7578 - iou: 0.4537 - val_loss: 0.7007 - val_accuracy: 0.7683 - val_iou: 0.4360
# Epoch 40/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.7608 - iou: 0.4622
# Epoch 40: val_iou did not improve from 0.44806
# 128/128 [==============================] - 97s 746ms/step - loss: 0.5891 - accuracy: 0.7608 - iou: 0.4622 - val_loss: 0.6930 - val_accuracy: 0.7720 - val_iou: 0.4412
# Epoch 41/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5911 - accuracy: 0.7602 - iou: 0.4613
# Epoch 41: val_iou did not improve from 0.44806
# 128/128 [==============================] - 98s 749ms/step - loss: 0.5911 - accuracy: 0.7602 - iou: 0.4613 - val_loss: 0.7413 - val_accuracy: 0.7411 - val_iou: 0.4215
# Epoch 42/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5918 - accuracy: 0.7610 - iou: 0.4560
# Epoch 42: val_iou did not improve from 0.44806
# 128/128 [==============================] - 113s 869ms/step - loss: 0.5918 - accuracy: 0.7610 - iou: 0.4560 - val_loss: 0.6788 - val_accuracy: 0.7725 - val_iou: 0.4477
# Epoch 43/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5898 - accuracy: 0.7613 - iou: 0.4635
# Epoch 43: val_iou did not improve from 0.44806
# 128/128 [==============================] - 99s 758ms/step - loss: 0.5898 - accuracy: 0.7613 - iou: 0.4635 - val_loss: 0.7352 - val_accuracy: 0.7512 - val_iou: 0.4246
# Epoch 44/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5856 - accuracy: 0.7634 - iou: 0.4657
# Epoch 44: val_iou did not improve from 0.44806
# 128/128 [==============================] - 113s 864ms/step - loss: 0.5856 - accuracy: 0.7634 - iou: 0.4657 - val_loss: 0.7175 - val_accuracy: 0.7719 - val_iou: 0.4389
# Epoch 45/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5832 - accuracy: 0.7635 - iou: 0.4675
# Epoch 45: val_iou did not improve from 0.44806
# 128/128 [==============================] - 112s 859ms/step - loss: 0.5832 - accuracy: 0.7635 - iou: 0.4675 - val_loss: 0.7009 - val_accuracy: 0.7661 - val_iou: 0.4452
# Epoch 46/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5885 - accuracy: 0.7608 - iou: 0.4651
# Epoch 46: val_iou did not improve from 0.44806
# 128/128 [==============================] - 113s 869ms/step - loss: 0.5885 - accuracy: 0.7608 - iou: 0.4651 - val_loss: 0.7923 - val_accuracy: 0.7253 - val_iou: 0.4067
# Epoch 47/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5862 - accuracy: 0.7616 - iou: 0.4624
# Epoch 47: val_iou did not improve from 0.44806
# 128/128 [==============================] - 99s 755ms/step - loss: 0.5862 - accuracy: 0.7616 - iou: 0.4624 - val_loss: 0.7429 - val_accuracy: 0.7442 - val_iou: 0.4188
# Epoch 48/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5813 - accuracy: 0.7646 - iou: 0.4648
# Epoch 48: val_iou did not improve from 0.44806
# 128/128 [==============================] - 113s 867ms/step - loss: 0.5813 - accuracy: 0.7646 - iou: 0.4648 - val_loss: 0.6883 - val_accuracy: 0.7667 - val_iou: 0.4419
# Epoch 49/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.7638 - iou: 0.4648
# Epoch 49: val_iou did not improve from 0.44806
# 128/128 [==============================] - 99s 757ms/step - loss: 0.5847 - accuracy: 0.7638 - iou: 0.4648 - val_loss: 0.7492 - val_accuracy: 0.7472 - val_iou: 0.4286
# Epoch 50/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.7635 - iou: 0.4591
# Epoch 50: val_iou did not improve from 0.44806
# 128/128 [==============================] - 112s 862ms/step - loss: 0.5847 - accuracy: 0.7635 - iou: 0.4591 - val_loss: 0.7031 - val_accuracy: 0.7659 - val_iou: 0.4463
# Epoch 51/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.7658 - iou: 0.4731
# Epoch 51: val_iou did not improve from 0.44806
# 128/128 [==============================] - 111s 855ms/step - loss: 0.5809 - accuracy: 0.7658 - iou: 0.4731 - val_loss: 0.6917 - val_accuracy: 0.7670 - val_iou: 0.4442
# Epoch 52/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.7657 - iou: 0.4720
# Epoch 52: val_iou did not improve from 0.44806
# 128/128 [==============================] - 98s 748ms/step - loss: 0.5796 - accuracy: 0.7657 - iou: 0.4720 - val_loss: 0.7732 - val_accuracy: 0.7371 - val_iou: 0.4046
# Epoch 53/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.7689 - iou: 0.4741
# Epoch 53: val_iou did not improve from 0.44806
# 128/128 [==============================] - 112s 858ms/step - loss: 0.5717 - accuracy: 0.7689 - iou: 0.4741 - val_loss: 0.7546 - val_accuracy: 0.7532 - val_iou: 0.4385
# Epoch 54/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5705 - accuracy: 0.7687 - iou: 0.4801
# Epoch 54: val_iou did not improve from 0.44806
# 128/128 [==============================] - 111s 853ms/step - loss: 0.5705 - accuracy: 0.7687 - iou: 0.4801 - val_loss: 0.7334 - val_accuracy: 0.7483 - val_iou: 0.4271
# Epoch 55/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5704 - accuracy: 0.7690 - iou: 0.4766
# Epoch 55: val_iou did not improve from 0.44806
# 128/128 [==============================] - 112s 858ms/step - loss: 0.5704 - accuracy: 0.7690 - iou: 0.4766 - val_loss: 0.7363 - val_accuracy: 0.7574 - val_iou: 0.4354
# Epoch 56/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5823 - accuracy: 0.7640 - iou: 0.4650
# Epoch 56: val_iou did not improve from 0.44806
# 128/128 [==============================] - 97s 734ms/step - loss: 0.5823 - accuracy: 0.7640 - iou: 0.4650 - val_loss: 0.7291 - val_accuracy: 0.7618 - val_iou: 0.4352
# Epoch 57/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5689 - accuracy: 0.7700 - iou: 0.4722
# Epoch 57: val_iou did not improve from 0.44806
# 128/128 [==============================] - 97s 738ms/step - loss: 0.5689 - accuracy: 0.7700 - iou: 0.4722 - val_loss: 0.6936 - val_accuracy: 0.7676 - val_iou: 0.4422
# Epoch 58/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.7697 - iou: 0.4769
# Epoch 58: val_iou did not improve from 0.44806
# 128/128 [==============================] - 112s 858ms/step - loss: 0.5708 - accuracy: 0.7697 - iou: 0.4769 - val_loss: 0.7167 - val_accuracy: 0.7592 - val_iou: 0.4398
# Epoch 59/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5750 - accuracy: 0.7679 - iou: 0.4670
# Epoch 59: val_iou did not improve from 0.44806
# 128/128 [==============================] - 111s 850ms/step - loss: 0.5750 - accuracy: 0.7679 - iou: 0.4670 - val_loss: 0.7568 - val_accuracy: 0.7516 - val_iou: 0.4260
# Epoch 60/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5664 - accuracy: 0.7708 - iou: 0.4775
# Epoch 60: val_iou improved from 0.44806 to 0.45279, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 113s 871ms/step - loss: 0.5664 - accuracy: 0.7708 - iou: 0.4775 - val_loss: 0.7070 - val_accuracy: 0.7696 - val_iou: 0.4528
# Epoch 61/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5712 - accuracy: 0.7692 - iou: 0.4788
# Epoch 61: val_iou did not improve from 0.45279
# 128/128 [==============================] - 97s 744ms/step - loss: 0.5712 - accuracy: 0.7692 - iou: 0.4788 - val_loss: 0.7692 - val_accuracy: 0.7331 - val_iou: 0.4208
# Epoch 62/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5676 - accuracy: 0.7697 - iou: 0.4809
# Epoch 62: val_iou did not improve from 0.45279
# 128/128 [==============================] - 97s 744ms/step - loss: 0.5676 - accuracy: 0.7697 - iou: 0.4809 - val_loss: 0.7978 - val_accuracy: 0.7354 - val_iou: 0.4164
# Epoch 63/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.7686 - iou: 0.4794
# Epoch 63: val_iou did not improve from 0.45279
# 128/128 [==============================] - 112s 863ms/step - loss: 0.5734 - accuracy: 0.7686 - iou: 0.4794 - val_loss: 0.8570 - val_accuracy: 0.6740 - val_iou: 0.3782
# Epoch 64/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5686 - accuracy: 0.7701 - iou: 0.4794
# Epoch 64: val_iou did not improve from 0.45279
# 128/128 [==============================] - 97s 738ms/step - loss: 0.5686 - accuracy: 0.7701 - iou: 0.4794 - val_loss: 0.6985 - val_accuracy: 0.7672 - val_iou: 0.4410
# Epoch 65/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5727 - accuracy: 0.7687 - iou: 0.4779
# Epoch 65: val_iou did not improve from 0.45279
# 128/128 [==============================] - 104s 785ms/step - loss: 0.5727 - accuracy: 0.7687 - iou: 0.4779 - val_loss: 0.7850 - val_accuracy: 0.7440 - val_iou: 0.4310
# Epoch 66/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5705 - accuracy: 0.7699 - iou: 0.4773
# Epoch 66: val_iou did not improve from 0.45279
# 128/128 [==============================] - 97s 745ms/step - loss: 0.5705 - accuracy: 0.7699 - iou: 0.4773 - val_loss: 0.7042 - val_accuracy: 0.7674 - val_iou: 0.4472
# Epoch 67/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5683 - accuracy: 0.7702 - iou: 0.4762
# Epoch 67: val_iou did not improve from 0.45279
# 128/128 [==============================] - 111s 849ms/step - loss: 0.5683 - accuracy: 0.7702 - iou: 0.4762 - val_loss: 0.7341 - val_accuracy: 0.7604 - val_iou: 0.4454
# Epoch 68/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5685 - accuracy: 0.7699 - iou: 0.4752
# Epoch 68: val_iou improved from 0.45279 to 0.45350, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 98s 750ms/step - loss: 0.5685 - accuracy: 0.7699 - iou: 0.4752 - val_loss: 0.7022 - val_accuracy: 0.7730 - val_iou: 0.4535
# Epoch 69/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.7732 - iou: 0.4754
# Epoch 69: val_iou did not improve from 0.45350
# 128/128 [==============================] - 112s 862ms/step - loss: 0.5616 - accuracy: 0.7732 - iou: 0.4754 - val_loss: 0.7357 - val_accuracy: 0.7473 - val_iou: 0.4321
# Epoch 70/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5601 - accuracy: 0.7741 - iou: 0.4809
# Epoch 70: val_iou improved from 0.45350 to 0.46058, saving model to segmentation_unet_transpose_conv.h5
# 128/128 [==============================] - 112s 862ms/step - loss: 0.5601 - accuracy: 0.7741 - iou: 0.4809 - val_loss: 0.6904 - val_accuracy: 0.7787 - val_iou: 0.4606
# Epoch 71/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5636 - accuracy: 0.7711 - iou: 0.4809
# Epoch 71: val_iou did not improve from 0.46058
# 128/128 [==============================] - 96s 730ms/step - loss: 0.5636 - accuracy: 0.7711 - iou: 0.4809 - val_loss: 0.6974 - val_accuracy: 0.7790 - val_iou: 0.4579
# Epoch 72/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5589 - accuracy: 0.7735 - iou: 0.4858
# Epoch 72: val_iou did not improve from 0.46058
# 128/128 [==============================] - 112s 862ms/step - loss: 0.5589 - accuracy: 0.7735 - iou: 0.4858 - val_loss: 0.7247 - val_accuracy: 0.7745 - val_iou: 0.4434
# Epoch 72: early stopping

# %%
history_unet_nearest_neighbor = model_unet_nearest_neighbor.fit(data_gen_train,
                              epochs=epochs,                                                     
                              validation_data=data_gen_val,                                                    
                              callbacks=cbks_unet_nearest_neighbor,
                              workers=4, 
                              use_multiprocessing=True,
                              max_queue_size=20
                              )
# Out:
# Epoch 1/200
# 128/128 [==============================] - ETA: 0s - loss: 1.1087 - accuracy: 0.5388 - iou: 0.2486
# Epoch 1: val_iou improved from -inf to 0.34063, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 116s 884ms/step - loss: 1.1087 - accuracy: 0.5388 - iou: 0.2486 - val_loss: 0.8997 - val_accuracy: 0.6726 - val_iou: 0.3406
# Epoch 2/200
# 128/128 [==============================] - ETA: 0s - loss: 0.8294 - accuracy: 0.6598 - iou: 0.3307
# Epoch 2: val_iou did not improve from 0.34063
# 128/128 [==============================] - 94s 718ms/step - loss: 0.8294 - accuracy: 0.6598 - iou: 0.3307 - val_loss: 0.9134 - val_accuracy: 0.6516 - val_iou: 0.3281
# Epoch 3/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7882 - accuracy: 0.6758 - iou: 0.3428
# Epoch 3: val_iou improved from 0.34063 to 0.35216, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 110s 847ms/step - loss: 0.7882 - accuracy: 0.6758 - iou: 0.3428 - val_loss: 0.8410 - val_accuracy: 0.6851 - val_iou: 0.3522
# Epoch 4/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7419 - accuracy: 0.6914 - iou: 0.3558
# Epoch 4: val_iou improved from 0.35216 to 0.38085, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 111s 851ms/step - loss: 0.7419 - accuracy: 0.6914 - iou: 0.3558 - val_loss: 0.7622 - val_accuracy: 0.7235 - val_iou: 0.3809
# Epoch 5/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7254 - accuracy: 0.6957 - iou: 0.3593
# Epoch 5: val_iou did not improve from 0.38085
# 128/128 [==============================] - 110s 838ms/step - loss: 0.7254 - accuracy: 0.6957 - iou: 0.3593 - val_loss: 0.8186 - val_accuracy: 0.6952 - val_iou: 0.3586
# Epoch 6/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.7160 - iou: 0.3799
# Epoch 6: val_iou improved from 0.38085 to 0.39806, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 111s 852ms/step - loss: 0.6895 - accuracy: 0.7160 - iou: 0.3799 - val_loss: 0.7583 - val_accuracy: 0.7424 - val_iou: 0.3981
# Epoch 7/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.7226 - iou: 0.3870
# Epoch 7: val_iou did not improve from 0.39806
# 128/128 [==============================] - 109s 841ms/step - loss: 0.6743 - accuracy: 0.7226 - iou: 0.3870 - val_loss: 0.7460 - val_accuracy: 0.7471 - val_iou: 0.3912
# Epoch 8/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.7327 - iou: 0.3944
# Epoch 8: val_iou improved from 0.39806 to 0.40093, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 96s 731ms/step - loss: 0.6565 - accuracy: 0.7327 - iou: 0.3944 - val_loss: 0.7658 - val_accuracy: 0.7454 - val_iou: 0.4009
# Epoch 9/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6213 - accuracy: 0.7490 - iou: 0.4218
# Epoch 9: val_iou improved from 0.40093 to 0.44087, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 96s 735ms/step - loss: 0.6213 - accuracy: 0.7490 - iou: 0.4218 - val_loss: 0.7110 - val_accuracy: 0.7782 - val_iou: 0.4409
# Epoch 10/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6064 - accuracy: 0.7592 - iou: 0.4357
# Epoch 10: val_iou improved from 0.44087 to 0.46352, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 111s 849ms/step - loss: 0.6064 - accuracy: 0.7592 - iou: 0.4357 - val_loss: 0.6980 - val_accuracy: 0.7838 - val_iou: 0.4635
# Epoch 11/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.7556 - iou: 0.4343
# Epoch 11: val_iou did not improve from 0.46352
# 128/128 [==============================] - 94s 728ms/step - loss: 0.6094 - accuracy: 0.7556 - iou: 0.4343 - val_loss: 0.8102 - val_accuracy: 0.7119 - val_iou: 0.3792
# Epoch 12/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5651 - accuracy: 0.7786 - iou: 0.4718
# Epoch 12: val_iou did not improve from 0.46352
# 128/128 [==============================] - 109s 837ms/step - loss: 0.5651 - accuracy: 0.7786 - iou: 0.4718 - val_loss: 0.8993 - val_accuracy: 0.6938 - val_iou: 0.3913
# Epoch 13/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5514 - accuracy: 0.7851 - iou: 0.4842
# Epoch 13: val_iou improved from 0.46352 to 0.47540, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 110s 845ms/step - loss: 0.5514 - accuracy: 0.7851 - iou: 0.4842 - val_loss: 0.6645 - val_accuracy: 0.7851 - val_iou: 0.4754
# Epoch 14/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5218 - accuracy: 0.7980 - iou: 0.4974
# Epoch 14: val_iou did not improve from 0.47540
# 128/128 [==============================] - 110s 841ms/step - loss: 0.5218 - accuracy: 0.7980 - iou: 0.4974 - val_loss: 0.6488 - val_accuracy: 0.7754 - val_iou: 0.4601
# Epoch 15/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5289 - accuracy: 0.7935 - iou: 0.4964
# Epoch 15: val_iou did not improve from 0.47540
# 128/128 [==============================] - 109s 833ms/step - loss: 0.5289 - accuracy: 0.7935 - iou: 0.4964 - val_loss: 0.7188 - val_accuracy: 0.7657 - val_iou: 0.4623
# Epoch 16/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.8019 - iou: 0.5091
# Epoch 16: val_iou did not improve from 0.47540
# 128/128 [==============================] - 94s 721ms/step - loss: 0.5147 - accuracy: 0.8019 - iou: 0.5091 - val_loss: 0.7734 - val_accuracy: 0.7371 - val_iou: 0.4145
# Epoch 17/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4943 - accuracy: 0.8104 - iou: 0.5162
# Epoch 17: val_iou improved from 0.47540 to 0.48560, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 110s 841ms/step - loss: 0.4943 - accuracy: 0.8104 - iou: 0.5162 - val_loss: 0.7059 - val_accuracy: 0.7803 - val_iou: 0.4856
# Epoch 18/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.8179 - iou: 0.5309
# Epoch 18: val_iou improved from 0.48560 to 0.50774, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 96s 736ms/step - loss: 0.4735 - accuracy: 0.8179 - iou: 0.5309 - val_loss: 0.6298 - val_accuracy: 0.8035 - val_iou: 0.5077
# Epoch 19/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.8262 - iou: 0.5453
# Epoch 19: val_iou improved from 0.50774 to 0.51484, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 96s 735ms/step - loss: 0.4482 - accuracy: 0.8262 - iou: 0.5453 - val_loss: 0.6437 - val_accuracy: 0.8098 - val_iou: 0.5148
# Epoch 20/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4354 - accuracy: 0.8323 - iou: 0.5544
# Epoch 20: val_iou did not improve from 0.51484
# 128/128 [==============================] - 92s 701ms/step - loss: 0.4354 - accuracy: 0.8323 - iou: 0.5544 - val_loss: 0.6346 - val_accuracy: 0.8089 - val_iou: 0.5145
# Epoch 21/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4309 - accuracy: 0.8320 - iou: 0.5542
# Epoch 21: val_iou improved from 0.51484 to 0.52252, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 109s 836ms/step - loss: 0.4309 - accuracy: 0.8320 - iou: 0.5542 - val_loss: 0.5929 - val_accuracy: 0.8141 - val_iou: 0.5225
# Epoch 22/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.8286 - iou: 0.5518
# Epoch 22: val_iou did not improve from 0.52252
# 128/128 [==============================] - 107s 823ms/step - loss: 0.4424 - accuracy: 0.8286 - iou: 0.5518 - val_loss: 0.6510 - val_accuracy: 0.7874 - val_iou: 0.4949
# Epoch 23/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4176 - accuracy: 0.8374 - iou: 0.5724
# Epoch 23: val_iou did not improve from 0.52252
# 128/128 [==============================] - 107s 823ms/step - loss: 0.4176 - accuracy: 0.8374 - iou: 0.5724 - val_loss: 0.6519 - val_accuracy: 0.7980 - val_iou: 0.5097
# Epoch 24/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4247 - accuracy: 0.8369 - iou: 0.5695
# Epoch 24: val_iou improved from 0.52252 to 0.52692, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 93s 709ms/step - loss: 0.4247 - accuracy: 0.8369 - iou: 0.5695 - val_loss: 0.5617 - val_accuracy: 0.8128 - val_iou: 0.5269
# Epoch 25/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8445 - iou: 0.5803
# Epoch 25: val_iou did not improve from 0.52692
# 128/128 [==============================] - 92s 705ms/step - loss: 0.4020 - accuracy: 0.8445 - iou: 0.5803 - val_loss: 0.6726 - val_accuracy: 0.7665 - val_iou: 0.4756
# Epoch 26/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3838 - accuracy: 0.8511 - iou: 0.5939
# Epoch 26: val_iou improved from 0.52692 to 0.52997, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 110s 842ms/step - loss: 0.3838 - accuracy: 0.8511 - iou: 0.5939 - val_loss: 0.5620 - val_accuracy: 0.8187 - val_iou: 0.5300
# Epoch 27/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8481 - iou: 0.5881
# Epoch 27: val_iou improved from 0.52997 to 0.54061, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 109s 840ms/step - loss: 0.3941 - accuracy: 0.8481 - iou: 0.5881 - val_loss: 0.5575 - val_accuracy: 0.8244 - val_iou: 0.5406
# Epoch 28/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4040 - accuracy: 0.8440 - iou: 0.5830
# Epoch 28: val_iou did not improve from 0.54061
# 128/128 [==============================] - 93s 712ms/step - loss: 0.4040 - accuracy: 0.8440 - iou: 0.5830 - val_loss: 0.6194 - val_accuracy: 0.8188 - val_iou: 0.5321
# Epoch 29/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8565 - iou: 0.6044
# Epoch 29: val_iou did not improve from 0.54061
# 128/128 [==============================] - 108s 829ms/step - loss: 0.3718 - accuracy: 0.8565 - iou: 0.6044 - val_loss: 0.5583 - val_accuracy: 0.8257 - val_iou: 0.5394
# Epoch 30/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3522 - accuracy: 0.8630 - iou: 0.6172
# Epoch 30: val_iou did not improve from 0.54061
# 128/128 [==============================] - 109s 834ms/step - loss: 0.3522 - accuracy: 0.8630 - iou: 0.6172 - val_loss: 0.5797 - val_accuracy: 0.8187 - val_iou: 0.5344
# Epoch 31/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.8649 - iou: 0.6262
# Epoch 31: val_iou did not improve from 0.54061
# 128/128 [==============================] - 109s 834ms/step - loss: 0.3477 - accuracy: 0.8649 - iou: 0.6262 - val_loss: 0.5647 - val_accuracy: 0.8160 - val_iou: 0.5360
# Epoch 32/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3407 - accuracy: 0.8678 - iou: 0.6405
# Epoch 32: val_iou did not improve from 0.54061
# 128/128 [==============================] - 95s 726ms/step - loss: 0.3407 - accuracy: 0.8678 - iou: 0.6405 - val_loss: 0.6078 - val_accuracy: 0.8093 - val_iou: 0.5272
# Epoch 33/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3532 - accuracy: 0.8641 - iou: 0.6431
# Epoch 33: val_iou did not improve from 0.54061
# 128/128 [==============================] - 109s 838ms/step - loss: 0.3532 - accuracy: 0.8641 - iou: 0.6431 - val_loss: 0.6279 - val_accuracy: 0.8048 - val_iou: 0.5205
# Epoch 34/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8721 - iou: 0.6359
# Epoch 34: val_iou improved from 0.54061 to 0.54476, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 110s 846ms/step - loss: 0.3316 - accuracy: 0.8721 - iou: 0.6359 - val_loss: 0.5835 - val_accuracy: 0.8280 - val_iou: 0.5448
# Epoch 35/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8757 - iou: 0.6420
# Epoch 35: val_iou did not improve from 0.54476
# 128/128 [==============================] - 111s 851ms/step - loss: 0.3211 - accuracy: 0.8757 - iou: 0.6420 - val_loss: 0.5924 - val_accuracy: 0.8148 - val_iou: 0.5327
# Epoch 36/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8806 - iou: 0.6796
# Epoch 36: val_iou did not improve from 0.54476
# 128/128 [==============================] - 95s 726ms/step - loss: 0.3071 - accuracy: 0.8806 - iou: 0.6796 - val_loss: 0.6807 - val_accuracy: 0.8199 - val_iou: 0.5294
# Epoch 37/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.8846 - iou: 0.6861
# Epoch 37: val_iou improved from 0.54476 to 0.55271, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 94s 720ms/step - loss: 0.2964 - accuracy: 0.8846 - iou: 0.6861 - val_loss: 0.5787 - val_accuracy: 0.8313 - val_iou: 0.5527
# Epoch 38/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8844 - iou: 0.6928
# Epoch 38: val_iou did not improve from 0.55271
# 128/128 [==============================] - 111s 848ms/step - loss: 0.2986 - accuracy: 0.8844 - iou: 0.6928 - val_loss: 0.5952 - val_accuracy: 0.8254 - val_iou: 0.5473
# Epoch 39/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8890 - iou: 0.7037
# Epoch 39: val_iou did not improve from 0.55271
# 128/128 [==============================] - 95s 728ms/step - loss: 0.2874 - accuracy: 0.8890 - iou: 0.7037 - val_loss: 0.5813 - val_accuracy: 0.8225 - val_iou: 0.5416
# Epoch 40/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2845 - accuracy: 0.8901 - iou: 0.7151
# Epoch 40: val_iou did not improve from 0.55271
# 128/128 [==============================] - 109s 839ms/step - loss: 0.2845 - accuracy: 0.8901 - iou: 0.7151 - val_loss: 0.7454 - val_accuracy: 0.7948 - val_iou: 0.5124
# Epoch 41/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.8945 - iou: 0.7173
# Epoch 41: val_iou did not improve from 0.55271
# 128/128 [==============================] - 109s 838ms/step - loss: 0.2732 - accuracy: 0.8945 - iou: 0.7173 - val_loss: 0.6049 - val_accuracy: 0.8235 - val_iou: 0.5490
# Epoch 42/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.9004 - iou: 0.7347
# Epoch 42: val_iou did not improve from 0.55271
# 128/128 [==============================] - 108s 833ms/step - loss: 0.2575 - accuracy: 0.9004 - iou: 0.7347 - val_loss: 0.6716 - val_accuracy: 0.8197 - val_iou: 0.5376
# Epoch 43/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8985 - iou: 0.7441
# Epoch 43: val_iou did not improve from 0.55271
# 128/128 [==============================] - 92s 704ms/step - loss: 0.2621 - accuracy: 0.8985 - iou: 0.7441 - val_loss: 0.6230 - val_accuracy: 0.8252 - val_iou: 0.5469
# Epoch 44/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8993 - iou: 0.7399
# Epoch 44: val_iou improved from 0.55271 to 0.55422, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 111s 849ms/step - loss: 0.2624 - accuracy: 0.8993 - iou: 0.7399 - val_loss: 0.5923 - val_accuracy: 0.8320 - val_iou: 0.5542
# Epoch 45/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9071 - iou: 0.7572
# Epoch 45: val_iou did not improve from 0.55422
# 128/128 [==============================] - 109s 840ms/step - loss: 0.2394 - accuracy: 0.9071 - iou: 0.7572 - val_loss: 0.5715 - val_accuracy: 0.8351 - val_iou: 0.5525
# Epoch 46/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9097 - iou: 0.7698
# Epoch 46: val_iou did not improve from 0.55422
# 128/128 [==============================] - 109s 841ms/step - loss: 0.2326 - accuracy: 0.9097 - iou: 0.7698 - val_loss: 0.6460 - val_accuracy: 0.8318 - val_iou: 0.5525
# Epoch 47/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 0.9160 - iou: 0.7642
# Epoch 47: val_iou did not improve from 0.55422
# 128/128 [==============================] - 93s 713ms/step - loss: 0.2174 - accuracy: 0.9160 - iou: 0.7642 - val_loss: 0.7206 - val_accuracy: 0.8244 - val_iou: 0.5489
# Epoch 48/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2128 - accuracy: 0.9182 - iou: 0.7863
# Epoch 48: val_iou improved from 0.55422 to 0.55571, saving model to segmentation_unet_nearest_neighbor.h5
# 128/128 [==============================] - 95s 731ms/step - loss: 0.2128 - accuracy: 0.9182 - iou: 0.7863 - val_loss: 0.6780 - val_accuracy: 0.8335 - val_iou: 0.5557
# Epoch 49/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2007 - accuracy: 0.9222 - iou: 0.7957
# Epoch 49: val_iou did not improve from 0.55571
# 128/128 [==============================] - 110s 847ms/step - loss: 0.2007 - accuracy: 0.9222 - iou: 0.7957 - val_loss: 0.6815 - val_accuracy: 0.8219 - val_iou: 0.5449
# Epoch 50/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9249 - iou: 0.7948
# Epoch 50: val_iou did not improve from 0.55571
# 128/128 [==============================] - 109s 836ms/step - loss: 0.1946 - accuracy: 0.9249 - iou: 0.7948 - val_loss: 0.7195 - val_accuracy: 0.8227 - val_iou: 0.5432
# Epoch 51/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9283 - iou: 0.7927
# Epoch 51: val_iou did not improve from 0.55571
# 128/128 [==============================] - 92s 703ms/step - loss: 0.1859 - accuracy: 0.9283 - iou: 0.7927 - val_loss: 0.6900 - val_accuracy: 0.8313 - val_iou: 0.5522
# Epoch 52/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9285 - iou: 0.8088
# Epoch 52: val_iou did not improve from 0.55571
# 128/128 [==============================] - 107s 827ms/step - loss: 0.1842 - accuracy: 0.9285 - iou: 0.8088 - val_loss: 0.7406 - val_accuracy: 0.8180 - val_iou: 0.5420
# Epoch 53/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9270 - iou: 0.7858
# Epoch 53: val_iou did not improve from 0.55571
# 128/128 [==============================] - 110s 844ms/step - loss: 0.1896 - accuracy: 0.9270 - iou: 0.7858 - val_loss: 0.7133 - val_accuracy: 0.8182 - val_iou: 0.5501
# Epoch 54/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9303 - iou: 0.8086
# Epoch 54: val_iou did not improve from 0.55571
# 128/128 [==============================] - 94s 721ms/step - loss: 0.1806 - accuracy: 0.9303 - iou: 0.8086 - val_loss: 0.7543 - val_accuracy: 0.8309 - val_iou: 0.5522
# Epoch 55/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9325 - iou: 0.8036
# Epoch 55: val_iou did not improve from 0.55571
# 128/128 [==============================] - 94s 715ms/step - loss: 0.1752 - accuracy: 0.9325 - iou: 0.8036 - val_loss: 0.7410 - val_accuracy: 0.8308 - val_iou: 0.5520
# Epoch 56/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9383 - iou: 0.8223
# Epoch 56: val_iou did not improve from 0.55571
# 128/128 [==============================] - 93s 712ms/step - loss: 0.1600 - accuracy: 0.9383 - iou: 0.8223 - val_loss: 0.7871 - val_accuracy: 0.8219 - val_iou: 0.5409
# Epoch 57/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9252 - iou: 0.8081
# Epoch 57: val_iou did not improve from 0.55571
# 128/128 [==============================] - 110s 842ms/step - loss: 0.1996 - accuracy: 0.9252 - iou: 0.8081 - val_loss: 0.6635 - val_accuracy: 0.8076 - val_iou: 0.5297
# Epoch 57: early stopping

# %%
history_unet_bilinear = model_unet_bilinear.fit(data_gen_train,
                              epochs=epochs,                                                     
                              validation_data=data_gen_val,                                                    
                              callbacks=cbks_unet_bilinear,
                              workers=4, 
                              use_multiprocessing=True,
                              max_queue_size=20
                              )
# Out:
# Epoch 1/200
# 128/128 [==============================] - ETA: 0s - loss: 1.3669 - accuracy: 0.5003 - iou: 0.2220
# Epoch 1: val_iou improved from -inf to 0.26809, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 109s 673ms/step - loss: 1.3669 - accuracy: 0.5003 - iou: 0.2220 - val_loss: 1.0292 - val_accuracy: 0.5789 - val_iou: 0.2681
# Epoch 2/200
# 128/128 [==============================] - ETA: 0s - loss: 0.8620 - accuracy: 0.6374 - iou: 0.3136
# Epoch 2: val_iou improved from 0.26809 to 0.31940, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 110s 845ms/step - loss: 0.8620 - accuracy: 0.6374 - iou: 0.3136 - val_loss: 0.8359 - val_accuracy: 0.6505 - val_iou: 0.3194
# Epoch 3/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7974 - accuracy: 0.6699 - iou: 0.3382
# Epoch 3: val_iou did not improve from 0.31940
# 128/128 [==============================] - 93s 709ms/step - loss: 0.7974 - accuracy: 0.6699 - iou: 0.3382 - val_loss: 0.9500 - val_accuracy: 0.6026 - val_iou: 0.2866
# Epoch 4/200
# 128/128 [==============================] - ETA: 0s - loss: 0.7574 - accuracy: 0.6866 - iou: 0.3512
# Epoch 4: val_iou improved from 0.31940 to 0.37522, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 96s 736ms/step - loss: 0.7574 - accuracy: 0.6866 - iou: 0.3512 - val_loss: 0.7538 - val_accuracy: 0.7417 - val_iou: 0.3752
# Epoch 5/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6988 - accuracy: 0.7144 - iou: 0.3777
# Epoch 5: val_iou improved from 0.37522 to 0.39167, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 96s 734ms/step - loss: 0.6988 - accuracy: 0.7144 - iou: 0.3777 - val_loss: 0.7361 - val_accuracy: 0.7386 - val_iou: 0.3917
# Epoch 6/200
# 128/128 [==============================] - 94s 722ms/step - loss: 0.6979 - accuracy: 0.7086 - iou: 0.3751 - val_loss: 0.8117 - val_accuracy: 0.7007 - val_iou: 0.3586
# Epoch 7/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6971 - accuracy: 0.7161 - iou: 0.3857
# Epoch 7: val_iou improved from 0.39167 to 0.40950, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 96s 736ms/step - loss: 0.6971 - accuracy: 0.7161 - iou: 0.3857 - val_loss: 0.7211 - val_accuracy: 0.7623 - val_iou: 0.4095
# Epoch 8/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.7367 - iou: 0.4153
# Epoch 8: val_iou improved from 0.40950 to 0.43053, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 96s 732ms/step - loss: 0.6470 - accuracy: 0.7367 - iou: 0.4153 - val_loss: 0.7563 - val_accuracy: 0.7656 - val_iou: 0.4305
# Epoch 9/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6115 - accuracy: 0.7562 - iou: 0.4445
# Epoch 9: val_iou improved from 0.43053 to 0.44035, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 109s 842ms/step - loss: 0.6115 - accuracy: 0.7562 - iou: 0.4445 - val_loss: 0.7594 - val_accuracy: 0.7563 - val_iou: 0.4404
# Epoch 10/200
# 128/128 [==============================] - ETA: 0s - loss: 0.6027 - accuracy: 0.7581 - iou: 0.4548
# Epoch 10: val_iou improved from 0.44035 to 0.46714, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 96s 739ms/step - loss: 0.6027 - accuracy: 0.7581 - iou: 0.4548 - val_loss: 0.7781 - val_accuracy: 0.7781 - val_iou: 0.4671
# Epoch 11/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.7673 - iou: 0.4634
# Epoch 11: val_iou did not improve from 0.46714
# 128/128 [==============================] - 110s 844ms/step - loss: 0.5847 - accuracy: 0.7673 - iou: 0.4634 - val_loss: 0.7147 - val_accuracy: 0.7838 - val_iou: 0.4520
# Epoch 12/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 0.7790 - iou: 0.4822
# Epoch 12: val_iou improved from 0.46714 to 0.47380, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 95s 728ms/step - loss: 0.5559 - accuracy: 0.7790 - iou: 0.4822 - val_loss: 0.6822 - val_accuracy: 0.7886 - val_iou: 0.4738
# Epoch 13/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5287 - accuracy: 0.7893 - iou: 0.5018
# Epoch 13: val_iou did not improve from 0.47380
# 128/128 [==============================] - 94s 719ms/step - loss: 0.5287 - accuracy: 0.7893 - iou: 0.5018 - val_loss: 0.6765 - val_accuracy: 0.7721 - val_iou: 0.4736
# Epoch 14/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5179 - accuracy: 0.7954 - iou: 0.5149
# Epoch 14: val_iou improved from 0.47380 to 0.49382, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 94s 722ms/step - loss: 0.5179 - accuracy: 0.7954 - iou: 0.5149 - val_loss: 0.6324 - val_accuracy: 0.8017 - val_iou: 0.4938
# Epoch 15/200
# 128/128 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.7950 - iou: 0.5056
# Epoch 15: val_iou improved from 0.49382 to 0.49794, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 111s 852ms/step - loss: 0.5186 - accuracy: 0.7950 - iou: 0.5056 - val_loss: 0.6433 - val_accuracy: 0.7956 - val_iou: 0.4979
# Epoch 16/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4985 - accuracy: 0.8059 - iou: 0.5288
# Epoch 16: val_iou did not improve from 0.49794
# 128/128 [==============================] - 109s 840ms/step - loss: 0.4985 - accuracy: 0.8059 - iou: 0.5288 - val_loss: 0.6927 - val_accuracy: 0.7747 - val_iou: 0.4776
# Epoch 17/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8120 - iou: 0.5299
# Epoch 17: val_iou did not improve from 0.49794
# 128/128 [==============================] - 93s 712ms/step - loss: 0.4802 - accuracy: 0.8120 - iou: 0.5299 - val_loss: 0.6796 - val_accuracy: 0.7684 - val_iou: 0.4626
# Epoch 18/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4552 - accuracy: 0.8233 - iou: 0.5514
# Epoch 18: val_iou improved from 0.49794 to 0.51846, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 95s 727ms/step - loss: 0.4552 - accuracy: 0.8233 - iou: 0.5514 - val_loss: 0.5908 - val_accuracy: 0.8089 - val_iou: 0.5185
# Epoch 19/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.8279 - iou: 0.5534
# Epoch 19: val_iou did not improve from 0.51846
# 128/128 [==============================] - 93s 712ms/step - loss: 0.4404 - accuracy: 0.8279 - iou: 0.5534 - val_loss: 0.6083 - val_accuracy: 0.8011 - val_iou: 0.5084
# Epoch 20/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8361 - iou: 0.5706
# Epoch 20: val_iou improved from 0.51846 to 0.52543, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 111s 855ms/step - loss: 0.4217 - accuracy: 0.8361 - iou: 0.5706 - val_loss: 0.5861 - val_accuracy: 0.8144 - val_iou: 0.5254
# Epoch 21/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4274 - accuracy: 0.8323 - iou: 0.5644
# Epoch 21: val_iou did not improve from 0.52543
# 128/128 [==============================] - 93s 716ms/step - loss: 0.4274 - accuracy: 0.8323 - iou: 0.5644 - val_loss: 0.5888 - val_accuracy: 0.8120 - val_iou: 0.5251
# Epoch 22/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.8434 - iou: 0.5814
# Epoch 22: val_iou improved from 0.52543 to 0.52978, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 111s 849ms/step - loss: 0.4018 - accuracy: 0.8434 - iou: 0.5814 - val_loss: 0.5668 - val_accuracy: 0.8176 - val_iou: 0.5298
# Epoch 23/200
# 128/128 [==============================] - ETA: 0s - loss: 0.4076 - accuracy: 0.8418 - iou: 0.5743
# Epoch 23: val_iou did not improve from 0.52978
# 128/128 [==============================] - 93s 716ms/step - loss: 0.4076 - accuracy: 0.8418 - iou: 0.5743 - val_loss: 0.5767 - val_accuracy: 0.8222 - val_iou: 0.5298
# Epoch 24/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.8479 - iou: 0.5886
# Epoch 24: val_iou did not improve from 0.52978
# 128/128 [==============================] - 94s 717ms/step - loss: 0.3898 - accuracy: 0.8479 - iou: 0.5886 - val_loss: 0.6274 - val_accuracy: 0.7985 - val_iou: 0.5154
# Epoch 25/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.8496 - iou: 0.5847
# Epoch 25: val_iou improved from 0.52978 to 0.53539, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 110s 848ms/step - loss: 0.3876 - accuracy: 0.8496 - iou: 0.5847 - val_loss: 0.6144 - val_accuracy: 0.8179 - val_iou: 0.5354
# Epoch 26/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8481 - iou: 0.5837
# Epoch 26: val_iou improved from 0.53539 to 0.53679, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 95s 729ms/step - loss: 0.3884 - accuracy: 0.8481 - iou: 0.5837 - val_loss: 0.5754 - val_accuracy: 0.8326 - val_iou: 0.5368
# Epoch 27/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8554 - iou: 0.6003
# Epoch 27: val_iou improved from 0.53679 to 0.54291, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 96s 730ms/step - loss: 0.3728 - accuracy: 0.8554 - iou: 0.6003 - val_loss: 0.6229 - val_accuracy: 0.8289 - val_iou: 0.5429
# Epoch 28/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3669 - accuracy: 0.8573 - iou: 0.6063
# Epoch 28: val_iou did not improve from 0.54291
# 128/128 [==============================] - 94s 719ms/step - loss: 0.3669 - accuracy: 0.8573 - iou: 0.6063 - val_loss: 0.6877 - val_accuracy: 0.8027 - val_iou: 0.5104
# Epoch 29/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8539 - iou: 0.5964
# Epoch 29: val_iou did not improve from 0.54291
# 128/128 [==============================] - 108s 833ms/step - loss: 0.3759 - accuracy: 0.8539 - iou: 0.5964 - val_loss: 0.6614 - val_accuracy: 0.8008 - val_iou: 0.5008
# Epoch 30/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8611 - iou: 0.6109
# Epoch 30: val_iou improved from 0.54291 to 0.54935, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 110s 844ms/step - loss: 0.3574 - accuracy: 0.8611 - iou: 0.6109 - val_loss: 0.5868 - val_accuracy: 0.8339 - val_iou: 0.5493
# Epoch 31/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8723 - iou: 0.6495
# Epoch 31: val_iou did not improve from 0.54935
# 128/128 [==============================] - 109s 839ms/step - loss: 0.3266 - accuracy: 0.8723 - iou: 0.6495 - val_loss: 0.7568 - val_accuracy: 0.7789 - val_iou: 0.4953
# Epoch 32/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.8680 - iou: 0.6534
# Epoch 32: val_iou did not improve from 0.54935
# 128/128 [==============================] - 109s 832ms/step - loss: 0.3360 - accuracy: 0.8680 - iou: 0.6534 - val_loss: 0.7031 - val_accuracy: 0.8202 - val_iou: 0.5399
# Epoch 33/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.8723 - iou: 0.6576
# Epoch 33: val_iou improved from 0.54935 to 0.55390, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 94s 716ms/step - loss: 0.3304 - accuracy: 0.8723 - iou: 0.6576 - val_loss: 0.6347 - val_accuracy: 0.8341 - val_iou: 0.5539
# Epoch 34/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.8829 - iou: 0.6680
# Epoch 34: val_iou did not improve from 0.55390
# 128/128 [==============================] - 94s 717ms/step - loss: 0.3007 - accuracy: 0.8829 - iou: 0.6680 - val_loss: 0.6129 - val_accuracy: 0.8155 - val_iou: 0.5393
# Epoch 35/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.8777 - iou: 0.6681
# Epoch 35: val_iou did not improve from 0.55390
# 128/128 [==============================] - 109s 836ms/step - loss: 0.3147 - accuracy: 0.8777 - iou: 0.6681 - val_loss: 0.7101 - val_accuracy: 0.8245 - val_iou: 0.5459
# Epoch 36/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8857 - iou: 0.6888
# Epoch 36: val_iou did not improve from 0.55390
# 128/128 [==============================] - 109s 834ms/step - loss: 0.2935 - accuracy: 0.8857 - iou: 0.6888 - val_loss: 0.5965 - val_accuracy: 0.8308 - val_iou: 0.5457
# Epoch 37/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.8907 - iou: 0.6923
# Epoch 37: val_iou did not improve from 0.55390
# 128/128 [==============================] - 109s 841ms/step - loss: 0.2821 - accuracy: 0.8907 - iou: 0.6923 - val_loss: 0.6909 - val_accuracy: 0.8269 - val_iou: 0.5485
# Epoch 38/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2698 - accuracy: 0.8949 - iou: 0.7256
# Epoch 38: val_iou did not improve from 0.55390
# 128/128 [==============================] - 109s 838ms/step - loss: 0.2698 - accuracy: 0.8949 - iou: 0.7256 - val_loss: 0.7699 - val_accuracy: 0.8248 - val_iou: 0.5424
# Epoch 39/200
# 128/128 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.8771 - iou: 0.6727
# Epoch 39: val_iou did not improve from 0.55390
# 128/128 [==============================] - 93s 711ms/step - loss: 0.3257 - accuracy: 0.8771 - iou: 0.6727 - val_loss: 0.7038 - val_accuracy: 0.8258 - val_iou: 0.5370
# Epoch 40/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.8921 - iou: 0.7038
# Epoch 40: val_iou did not improve from 0.55390
# 128/128 [==============================] - 94s 715ms/step - loss: 0.2788 - accuracy: 0.8921 - iou: 0.7038 - val_loss: 0.6641 - val_accuracy: 0.8207 - val_iou: 0.5399
# Epoch 41/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.8948 - iou: 0.6790
# Epoch 41: val_iou did not improve from 0.55390
# 128/128 [==============================] - 93s 712ms/step - loss: 0.2705 - accuracy: 0.8948 - iou: 0.6790 - val_loss: 0.6423 - val_accuracy: 0.8249 - val_iou: 0.5442
# Epoch 42/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.9033 - iou: 0.7274
# Epoch 42: val_iou did not improve from 0.55390
# 128/128 [==============================] - 94s 714ms/step - loss: 0.2500 - accuracy: 0.9033 - iou: 0.7274 - val_loss: 0.7036 - val_accuracy: 0.8206 - val_iou: 0.5443
# Epoch 43/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.9041 - iou: 0.7313
# Epoch 43: val_iou did not improve from 0.55390
# 128/128 [==============================] - 93s 712ms/step - loss: 0.2486 - accuracy: 0.9041 - iou: 0.7313 - val_loss: 0.7787 - val_accuracy: 0.8202 - val_iou: 0.5415
# Epoch 44/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.9101 - iou: 0.7540
# Epoch 44: val_iou did not improve from 0.55390
# 128/128 [==============================] - 93s 713ms/step - loss: 0.2325 - accuracy: 0.9101 - iou: 0.7540 - val_loss: 0.7668 - val_accuracy: 0.8252 - val_iou: 0.5507
# Epoch 45/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9162 - iou: 0.7656
# Epoch 45: val_iou did not improve from 0.55390
# 128/128 [==============================] - 109s 833ms/step - loss: 0.2162 - accuracy: 0.9162 - iou: 0.7656 - val_loss: 0.7291 - val_accuracy: 0.8240 - val_iou: 0.5479
# Epoch 46/200
# 128/128 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9186 - iou: 0.7834
# Epoch 46: val_iou did not improve from 0.55390
# 128/128 [==============================] - 94s 717ms/step - loss: 0.2084 - accuracy: 0.9186 - iou: 0.7834 - val_loss: 0.7110 - val_accuracy: 0.8273 - val_iou: 0.5505
# Epoch 47/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9227 - iou: 0.7894
# Epoch 47: val_iou did not improve from 0.55390
# 128/128 [==============================] - 109s 838ms/step - loss: 0.1984 - accuracy: 0.9227 - iou: 0.7894 - val_loss: 0.8737 - val_accuracy: 0.8175 - val_iou: 0.5400
# Epoch 48/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9255 - iou: 0.7987
# Epoch 48: val_iou improved from 0.55390 to 0.55428, saving model to segmentation_unet_bilinear.h5
# 128/128 [==============================] - 95s 726ms/step - loss: 0.1915 - accuracy: 0.9255 - iou: 0.7987 - val_loss: 0.7671 - val_accuracy: 0.8287 - val_iou: 0.5543
# Epoch 49/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9270 - iou: 0.8090
# Epoch 49: val_iou did not improve from 0.55428
# 128/128 [==============================] - 94s 717ms/step - loss: 0.1868 - accuracy: 0.9270 - iou: 0.8090 - val_loss: 0.8810 - val_accuracy: 0.8235 - val_iou: 0.5397
# Epoch 50/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9277 - iou: 0.7916
# Epoch 50: val_iou did not improve from 0.55428
# 128/128 [==============================] - 93s 712ms/step - loss: 0.1872 - accuracy: 0.9277 - iou: 0.7916 - val_loss: 0.9106 - val_accuracy: 0.8243 - val_iou: 0.5340
# Epoch 51/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1863 - accuracy: 0.9283 - iou: 0.7820
# Epoch 51: val_iou did not improve from 0.55428
# 128/128 [==============================] - 93s 712ms/step - loss: 0.1863 - accuracy: 0.9283 - iou: 0.7820 - val_loss: 0.7875 - val_accuracy: 0.8218 - val_iou: 0.5244
# Epoch 52/200
# 128/128 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9265 - iou: 0.7258
# Epoch 52: val_iou did not improve from 0.55428
# 128/128 [==============================] - 93s 714ms/step - loss: 0.1926 - accuracy: 0.9265 - iou: 0.7258 - val_loss: 0.6864 - val_accuracy: 0.8248 - val_iou: 0.5480
# Epoch 52: early stopping

# %% [markdown]
# ### Load trained model

# %%
model_unet_transpose_conv.load_weights("segmentation_unet_transpose_conv.h5")
model_unet_nearest_neighbor.load_weights("segmentation_unet_nearest_neighbor.h5")
model_unet_bilinear.load_weights("segmentation_unet_bilinear.h5")

# %% [markdown]
# ## Model evaluation
# Let's compute the metrics and loss function values for the trained model.

# %%
data_gen_test = DataGenerator(batch_size=batch_size,
                              patch_size=patch_size,
                              step_size=step_size,
                              list_top=list_top_test, 
                              list_gts=list_gts_test,
                              n_classes=n_classes,
                              colormap_gt=color2index
                              )

# %%
print("Train:")
scores_train = model_unet_transpose_conv.evaluate(data_gen_train)

print("Validation:")
scores_val = model_unet_transpose_conv.evaluate(data_gen_val)

print("Test:")
scores_test = model_unet_transpose_conv.evaluate(data_gen_test)
# Out:
# Train:
# 128/128 [==============================] - 95s 620ms/step - loss: 0.5415 - accuracy: 0.7822 - iou: 0.4957
# Validation:
# 38/38 [==============================] - 22s 579ms/step - loss: 0.6904 - accuracy: 0.7787 - iou: 0.4606
# Test:
# 190/190 [==============================] - 140s 738ms/step - loss: 0.6301 - accuracy: 0.7591 - iou: 0.4441

# %%
print("Train:")
scores_train = model_unet_nearest_neighbor.evaluate(data_gen_train)

print("Validation:")
scores_val = model_unet_nearest_neighbor.evaluate(data_gen_val)

print("Test:")
scores_test = model_unet_nearest_neighbor.evaluate(data_gen_test)
# Out:
# Train:
# 128/128 [==============================] - 71s 535ms/step - loss: 0.1758 - accuracy: 0.9321 - iou: 0.8221
# Validation:
# 38/38 [==============================] - 19s 490ms/step - loss: 0.6780 - accuracy: 0.8335 - iou: 0.5557
# Test:
# 190/190 [==============================] - 108s 569ms/step - loss: 0.6541 - accuracy: 0.8177 - iou: 0.5634

# %%
print("Train:")
scores_train = model_unet_bilinear.evaluate(data_gen_train)

print("Validation:")
scores_val = model_unet_bilinear.evaluate(data_gen_val)

print("Test:")
scores_test = model_unet_bilinear.evaluate(data_gen_test)
# Out:
# Train:
# 128/128 [==============================] - 69s 536ms/step - loss: 0.1571 - accuracy: 0.9390 - iou: 0.8246
# Validation:
# 38/38 [==============================] - 19s 487ms/step - loss: 0.7671 - accuracy: 0.8287 - iou: 0.5543
# Test:
# 190/190 [==============================] - 109s 574ms/step - loss: 0.6556 - accuracy: 0.8225 - iou: 0.5897

# %% [markdown]
# ## Visualization of the predictions

# %%
#@title Predictions Visualization { run: "auto"}
#@markdown Select a sample
id_batch = 64 #@param {type:"slider", min:0, max:189, step:1}

# Get a batch from the generator for testing
x,y = data_gen_test.__getitem__(id_batch)
# Obtain the prediction from the trained model
prediction1 = model_unet_transpose_conv.predict(x)
prediction2 = model_unet_bilinear.predict(x)
prediction3 = model_unet_nearest_neighbor.predict(x)
# Iterate over each sample in the batch
for x_i,y_i,p_1,p_2,p_3 in zip(x,y,
                                        prediction1,
                                        prediction2,
                                        prediction3):
                                        
  # For visualization: [0,1] => [0,255]
  x_i = x_i*255
  x_i = x_i.astype(np.uint8)
  # From one hot encoding to integer
  gt = np.argmax(y_i, axis=-1)
  pred1 = np.argmax(p_1, axis=-1)
  pred2 = np.argmax(p_2, axis=-1)
  pred3 = np.argmax(p_3, axis=-1)
  # Object to compute the mean IoU
  m_iou = OneHotMeanIoU(num_classes=n_classes)
  m_iou.update_state(y_true=y_i, 
                     y_pred=p_1)
  m_iou2 = OneHotMeanIoU(num_classes=n_classes)
  m_iou2.update_state(y_true=y_i, 
                     y_pred=p_2)
  m_iou3 = OneHotMeanIoU(num_classes=n_classes)
  m_iou3.update_state(y_true=y_i, 
                     y_pred=p_3)
  # List to storage IoU per class
  iou_all1 = []
  iou_all2 = []
  iou_all3 = []
  for id_class in range(n_classes):
    # Object to compute the IoU for each class
    m_iou_class = OneHotIoU(num_classes=n_classes, 
                            target_class_ids=[id_class])
    m_iou_class.update_state(y_true=y_i, 
                             y_pred=p_1)
    m_iou_class2 = OneHotIoU(num_classes=n_classes, 
                            target_class_ids=[id_class])
    m_iou_class2.update_state(y_true=y_i, 
                             y_pred=p_2)
    m_iou_class3 = OneHotIoU(num_classes=n_classes, 
                            target_class_ids=[id_class])
    m_iou_class3.update_state(y_true=y_i, 
                             y_pred=p_3)
    # Save IoU for each class
    iou_all1.append(m_iou_class.result().numpy())
    iou_all2.append(m_iou_class.result().numpy())
    iou_all3.append(m_iou_class.result().numpy())
  # Colo images for the Ground Truth and Prediction
  gt_rgb = np.zeros((gt.shape[0],gt.shape[1],3), dtype=np.uint8)
  pred1_rgb = np.zeros((gt.shape[0],gt.shape[1],3), dtype=np.uint8)
  pred2_rgb = np.zeros((gt.shape[0],gt.shape[1],3), dtype=np.uint8)
  pred3_rgb = np.zeros((gt.shape[0],gt.shape[1],3), dtype=np.uint8)
  # Assign a color to each integer value from the given dictionary
  for key,value in color2index.items():
    gt_rgb[gt==value] = key
    pred1_rgb[pred1==value] = key
    pred2_rgb[pred2==value] = key
    pred3_rgb[pred3==value] = key
  # Visualization
  plt.figure(figsize=(18,3))
  plt.subplot(1,6,1)
  plt.imshow(x_i)
  plt.title("RGB image")
  plt.axis("off")

  # Ground Truth
  plt.subplot(1,6,2)
  plt.imshow(gt_rgb)
  plt.title("Reference")
  plt.axis("off")

  # Prediction U-Net conv
  plt.subplot(1,6,3)
  plt.imshow(pred1_rgb)
  plt.title("Prediction\nmIoU={:.2f}\n{}".format(m_iou.result().numpy(),
                                                 np.round(iou_all1, decimals=2)))
  plt.axis("off")
  # Prediction U-Net bilinear
  plt.subplot(1,6,4)
  plt.imshow(pred2_rgb)
  plt.title("U-Net bilinear.\nmIoU={:.2f}\n{}".format(m_iou2.result().numpy(),
                                                      np.round(iou_all2, decimals=2)))
  plt.axis("off")
  # Prediction U-Net nearest_neighbor
  plt.subplot(1,6,5)
  plt.imshow(pred3_rgb)
  plt.title("U-Net nearest_neighbor\nmIoU={:.2f}\n{}".format(m_iou3.result().numpy(),
                                                             np.round(iou_all3, decimals=2)))

  plt.axis("off")
  # Colormap
  g = plt.subplot(1,6,6)
  g.axes.set_xlim(0,3.4)
  g.axes.set_ylim(-0.01,0.55)

  g.text(0, 0.025, "Impervious surfaces")
  g.text(0, 0.125, "Building ")
  g.text(0, 0.225, "Low vegetation")
  g.text(0, 0.325, "Tree ")
  g.text(0, 0.425, "Car ")
  g.text(0, 0.525, "Clutter/background")

  x_rec = 2.3
  g.add_patch(patches.Rectangle((x_rec,0.0), 1, 0.05, facecolor="#FFFFFF", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.1), 1, 0.05, facecolor="#0000FF", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.2), 1, 0.05, facecolor="#00FFFF", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.3), 1, 0.05, facecolor="#00FF00", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.4), 1, 0.05, facecolor="#FFFF00", edgecolor="black"))
  g.add_patch(patches.Rectangle((x_rec,0.5), 1, 0.05, facecolor="#FF0000", edgecolor="black"))
  g.axis("off")

  plt.tight_layout()

  plt.show()
